# %% [markdown]
# # Projeto Ciencia de Dados: Carteira de Ações com Inteligência Artificial
#
# - Projeto Inspiração: https://medium.com/swlh/teaching-a-machine-to-trade-stocks-like-warren-buffett-part-i-445849b208c6
# - Resumo Fundamentos Empresas BR: https://fundamentus.com.br/index.php

# %% [markdown]
# ### Criar Dicionários de Dataframes com cada empresa
# * selecione todas as 77 empresas que fazem parte do IBOVESPA.

# %%
import pandas as pd
import os
empresas = ["ABEV3", "AZUL4", "BTOW3", "B3SA3", "BBSE3", "BRML3", "BBDC4", "BRAP4", "BBAS3", "BRKM5", "BRFS3", "BPAC11", "CRFB3", "CCRO3", "CMIG4", "HGTX3", "CIEL3", "COGN3", "CPLE6", "CSAN3", "CPFE3", "CVCB3", "CYRE3", "ECOR3", "ELET6", "EMBR3", "ENBR3", "ENGI11", "ENEV3", "EGIE3", "EQTL3", "EZTC3", "FLRY3", "GGBR4", "GOAU4", "GOLL4", "NTCO3", "HAPV3", "HYPE3", "IGTA3", "GNDI3", "ITSA4", "ITUB4", "JBSS3", "JHSF3", "KLBN11", "RENT3", "LCAM3", "LAME4", "LREN3", "MGLU3", "MRFG3", "BEEF3", "MRVE3", "MULT3", "PCAR3", "PETR4", "BRDT3", "PRIO3", "QUAL3", "RADL3", "RAIL3", "SBSP3", "SANB11", "CSNA3", "SULA11", "SUZB3", "TAEE11", "VIVT3", "TIMS3", "TOTS3", "UGPA3", "USIM5", "VALE3", "VVAR3", "WEGE3", "YDUQ3"]
# fundamentos = {
#     "ABEV3": balanco_dre_abev3,
#     "MGLU3": balanco_dre_mglu3
# }
arquivos = os.listdir("balancos")
for arquivo in arquivos:
    print(arquivo)
# Out:
# balancos.zip
# balanco_ABEV3.xls
# balanco_ASAI3.xls
# balanco_AZUL4.xls
# balanco_B3SA3.xls
# balanco_BBAS3.xls
# balanco_BBDC3.xls
# balanco_BBDC4.xls
# balanco_BBSE3.xls
# balanco_BEEF3.xls
# balanco_BPAC11.xls
# balanco_BRAP4.xls
# balanco_BRDT3.xls
# balanco_BRFS3.xls
# balanco_BRKM5.xls
# balanco_BRML3.xls
# balanco_BTOW3.xls
# balanco_CCRO3.xls
# balanco_CIEL3.xls
# balanco_CMIG4.xls
# balanco_COGN3.xls
# balanco_CPFE3.xls
# balanco_CPLE6.xls
# balanco_CRFB3.xls
# balanco_CSAN3.xls
# balanco_CSNA3.xls
# balanco_CVCB3.xls
# balanco_CYRE3.xls
# balanco_ECOR3.xls
# balanco_EGIE3.xls
# balanco_ELET3.xls
# balanco_ELET6.xls
# balanco_EMBR3.xls
# balanco_ENBR3.xls
# balanco_ENEV3.xls
# balanco_ENGI11.xls
# balanco_EQTL3.xls
# balanco_EZTC3.xls
# balanco_FLRY3.xls
# balanco_GGBR4.xls
# balanco_GNDI3.xls
# balanco_GOAU4.xls
# balanco_GOLL4.xls
# balanco_HAPV3.xls
# balanco_HGTX3.xls
# balanco_HYPE3.xls
# balanco_IGTA3.xls
# balanco_ITSA4.xls
# balanco_ITUB4.xls
# balanco_JBSS3.xls
# balanco_JHSF3.xls
# balanco_KLBN11.xls
# balanco_LAME4.xls
# balanco_LCAM3.xls
# balanco_LREN3.xls
# balanco_MGLU3.xls
# balanco_MRFG3.xls
# balanco_MRVE3.xls
# balanco_MULT3.xls
# balanco_NTCO3.xls
# balanco_PCAR3.xls
# balanco_PETR3.xls
# balanco_PETR4.xls
# balanco_PRIO3.xls
# balanco_QUAL3.xls
# balanco_RADL3.xls
# balanco_RAIL3.xls
# balanco_RENT3.xls
# balanco_SANB11.xls
# balanco_SBSP3.xls
# balanco_SULA11.xls
# balanco_SUZB3.xls
# balanco_TAEE11.xls
# balanco_TIMS3.xls
# balanco_TOTS3.xls
# balanco_UGPA3.xls
# balanco_USIM5.xls
# balanco_VALE3.xls
# balanco_VIVT3.xls
# balanco_VVAR3.xls
# balanco_WEGE3.xls
# balanco_YDUQ3.xls

# %%
fundamentos= {}
arquivos = os.listdir("balancos")
for arquivo in arquivos:
    nome = arquivo[-9:-4]
    if "11" in nome:
        nome = arquivo[-10:-4]
    if nome in empresas:
        print(nome)
        # pegar o balanco daquela empresa
        balanco = pd.read_excel(f'balancos/{arquivo}', sheet_name=0)
        # na primeira coluna colocar o título com o nome da empresa
        balanco.iloc[0, 0] = nome
        # pegar 1ª linha e tornar um cabeçalho
        balanco.columns = balanco.iloc[0]
        balanco = balanco[1:]        
        # tornar a 1ª coluna (que agora tem o nome da emrpesa)
        balanco = balanco.set_index(nome)
        dre = pd.read_excel(f'balancos/{arquivo}', sheet_name=1)
        # na primeira coluna colocar o título com o nome da empresa
        dre.iloc[0, 0] = nome
        # pegar 1ª linha e tornar um cabeçalho
        dre.columns = dre.iloc[0]
        dre = dre[1:]        
        # tornar a 1ª coluna (que agora tem o nome da emrpesa)
        dre = dre.set_index(nome)
        fundamentos[nome] = balanco.append(dre)
# Out:
# ABEV3
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# AZUL4
# WARNING *** file size (30309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (30309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# B3SA3
# WARNING *** file size (64274) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64274) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BBAS3
# WARNING *** file size (68412) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (68412) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BBDC4
# WARNING *** file size (68284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (68284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BBSE3
# WARNING *** file size (16355) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (16355) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BEEF3
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BPAC11
# WARNING *** file size (66667) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (66667) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BRAP4
# WARNING *** file size (64404) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64404) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BRDT3
# WARNING *** file size (30325) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (30325) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BRFS3
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BRKM5
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BRML3
# WARNING *** file size (64322) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64322) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BTOW3
# WARNING *** file size (64334) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64334) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CCRO3
# WARNING *** file size (64340) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64340) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CIEL3
# WARNING *** file size (64136) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64136) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CMIG4
# WARNING *** file size (64388) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64388) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# COGN3
# WARNING *** file size (64388) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64388) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CPFE3
# WARNING *** file size (64412) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64412) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CPLE6
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CRFB3
# WARNING *** file size (30325) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (30325) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CSAN3
# WARNING *** file size (64107) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64107) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CSNA3
# WARNING *** file size (64276) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64276) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CVCB3
# WARNING *** file size (50451) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (50451) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CYRE3
# WARNING *** file size (64310) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64310) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ECOR3
# WARNING *** file size (64292) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64292) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# EGIE3
# WARNING *** file size (64296) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64296) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ELET6
# WARNING *** file size (64398) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64398) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# EMBR3
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ENBR3
# WARNING *** file size (64322) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64322) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ENEV3
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ENGI11
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# EQTL3
# WARNING *** file size (64424) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64424) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# EZTC3
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# FLRY3
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# GGBR4
# WARNING *** file size (64256) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64256) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# GNDI3
# WARNING *** file size (24955) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (24955) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# GOAU4
# WARNING *** file size (64270) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64270) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# GOLL4
# WARNING *** file size (64336) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64336) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# HAPV3
# WARNING *** file size (24947) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (24947) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# HGTX3
# WARNING *** file size (64290) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64290) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# HYPE3
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# IGTA3
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ITSA4
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ITUB4
# WARNING *** file size (68522) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (68522) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# JBSS3
# WARNING *** file size (64330) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64330) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# JHSF3
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# KLBN11
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# LAME4
# WARNING *** file size (64312) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64312) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# LCAM3
# WARNING *** file size (62367) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (62367) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# LREN3
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# MGLU3
# WARNING *** file size (62531) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (62531) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# MRFG3
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# MRVE3
# WARNING *** file size (64276) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64276) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# MULT3
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# NTCO3
# WARNING *** file size (15892) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (15892) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# PCAR3
# WARNING *** file size (64296) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64296) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# PETR4
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# PRIO3
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# QUAL3
# WARNING *** file size (61185) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (61185) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# RADL3
# WARNING *** file size (64060) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64060) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# RAIL3
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# RENT3
# WARNING *** file size (64308) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64308) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# SANB11
# WARNING *** file size (68210) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (68210) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# SBSP3
# WARNING *** file size (63832) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (63832) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# SULA11
# WARNING *** file size (64292) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64292) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# SUZB3
# WARNING *** file size (64294) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64294) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# TAEE11
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# TIMS3
# WARNING *** file size (19427) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (19427) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# TOTS3
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# UGPA3
# WARNING *** file size (64320) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64320) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# USIM5
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# VALE3
# WARNING *** file size (64278) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64278) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# VIVT3
# WARNING *** file size (64294) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64294) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# VVAR3
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WEGE3
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# YDUQ3
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
print(fundamentos)
# Out:
# {'ABEV3':                                            31/12/2020   30/09/2020  \
# ABEV3
# Ativo Total                               1.25197e+08  1.27057e+08
# Ativo Circulante                          3.53426e+07  3.90988e+07
# Caixa e Equivalentes de Caixa             1.70903e+07  2.16605e+07
# Aplicações Financeiras                    1.70003e+06  1.44292e+06
# Contas a Receber                          4.30314e+06  4.15692e+06
# ...                                               ...          ...
# IR Diferido                              -1.66758e+06       343476
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores         -104363       -84167
# Lucro/Prejuízo do Período                 6.78601e+06   2.2748e+06
#
#                                            30/06/2020   31/03/2020  \
# ABEV3
# Ativo Total                               1.21393e+08  1.13688e+08
# Ativo Circulante                          3.62681e+07  3.10864e+07
# Caixa e Equivalentes de Caixa              1.7439e+07  1.32045e+07
# Aplicações Financeiras                          44823        44823
# Contas a Receber                          4.20158e+06   3.3943e+06
# ...                                               ...          ...
# IR Diferido                                    595088        15365
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores          -44517      -119468
# Lucro/Prejuízo do Período                  1.2268e+06  1.09178e+06
#
#                                            31/12/2019   30/09/2019  \
# ABEV3
# Ativo Total                               1.01743e+08  1.02475e+08
# Ativo Circulante                          2.76211e+07   2.9004e+07
# Caixa e Equivalentes de Caixa             1.19007e+07  1.50169e+07
# Aplicações Financeiras                          14558        14304
# Contas a Receber                          4.49552e+06  4.23626e+06
# ...                                               ...          ...
# IR Diferido                                   -853995       427238
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores         -119273      -106708
# Lucro/Prejuízo do Período                  4.0997e+06  2.49768e+06
#
#                                            30/06/2019   31/03/2019  \
# ABEV3
# Ativo Total                                9.8739e+07  9.69055e+07
# Ativo Circulante                           2.7356e+07  2.61941e+07
# Caixa e Equivalentes de Caixa             1.42334e+07  1.28225e+07
# Aplicações Financeiras                          14038        13772
# Contas a Receber                          4.10312e+06  3.98036e+06
# ...                                               ...          ...
# IR Diferido                                    443414       346724
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores          -95168       -87218
# Lucro/Prejuízo do Período                 2.52073e+06  2.66185e+06
#
#                                            31/12/2018   30/09/2018  ...  \
# ABEV3                                                               ...
# Ativo Total                               9.41261e+07   9.5691e+07  ...
# Ativo Circulante                          2.53296e+07     2.62e+07  ...
# Caixa e Equivalentes de Caixa             1.14635e+07  1.22277e+07  ...
# Aplicações Financeiras                          13391        13008  ...
# Contas a Receber                          4.87926e+06  4.28563e+06  ...
# ...                                               ...          ...  ...
# IR Diferido                              -1.16093e+06       612890  ...
# Participações/Contribuições Estatutárias          NaN          NaN  ...
# Reversão dos Juros sobre Capital Próprio          NaN          NaN  ...
# Part. de Acionistas Não Controladores         -103126       -60947  ...
# Lucro/Prejuízo do Período                  3.3604e+06  2.83116e+06  ...
#
#                                            31/03/2015   31/12/2014  \
# ABEV3
# Ativo Total                                  75101184  7.21432e+07
# Ativo Circulante                           1.9241e+07  2.07284e+07
# Caixa e Equivalentes de Caixa             6.97458e+06  9.72207e+06
# Aplicações Financeiras                    1.03376e+06       712958
# Contas a Receber                           2.8977e+06  3.02885e+06
# ...                                               ...          ...
# IR Diferido                                    -28029      -859414
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores         -152180      -120675
# Lucro/Prejuízo do Período                 2.81066e+06  4.53839e+06
#
#                                            30/09/2014   30/06/2014  \
# ABEV3
# Ativo Total                               6.51259e+07   6.2989e+07
# Ativo Circulante                          1.54466e+07  1.57733e+07
# Caixa e Equivalentes de Caixa             5.74812e+06  6.27386e+06
# Aplicações Financeiras                         526789       379938
# Contas a Receber                          3.27564e+06  3.53838e+06
# ...                                               ...          ...
# IR Diferido                                    475888        30916
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores          -76946       -48724
# Lucro/Prejuízo do Período                  2.8136e+06  2.16688e+06
#
#                                            31/03/2014   31/12/2013  \
# ABEV3
# Ativo Total                                6.3297e+07   6.8674e+07
# Ativo Circulante                          1.63523e+07    2.047e+07
# Caixa e Equivalentes de Caixa             7.29618e+06  1.12858e+07
# Aplicações Financeiras                         410173       288604
# Contas a Receber                          3.11009e+06  3.61351e+06
# ...                                               ...          ...
# IR Diferido                                    403236      -197098
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores          -50162     -85133.1
# Lucro/Prejuízo do Período                 2.54664e+06  6.09375e+06
#
#                                            30/09/2013   30/06/2013  \
# ABEV3
# Ativo Total                                5.9619e+07  5.87393e+07
# Ativo Circulante                          1.24784e+07  1.20571e+07
# Caixa e Equivalentes de Caixa             4.83517e+06  4.48217e+06
# Aplicações Financeiras                         612489       486133
# Contas a Receber                          2.74785e+06  2.78314e+06
# ...                                               ...          ...
# IR Diferido                                   -462300       114066
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores          -49296      -758399
# Lucro/Prejuízo do Período                 2.28971e+06  1.14174e+06
#
#                                            31/03/2013  31/12/2012
# ABEV3
# Ativo Total                               1.34037e+06  1.3463e+06
# Ativo Circulante                                77552       71641
# Caixa e Equivalentes de Caixa                   74204       48155
# Aplicações Financeiras                              0           0
# Contas a Receber                                 3105       21490
# ...                                               ...         ...
# IR Diferido                                       -70         NaN
# Participações/Contribuições Estatutárias          NaN         NaN
# Reversão dos Juros sobre Capital Próprio          NaN         NaN
# Part. de Acionistas Não Controladores             NaN         NaN
# Lucro/Prejuízo do Período                        9768         NaN
#
# [79 rows x 33 columns], 'AZUL4':                                            31/12/2020   30/09/2020  \
# AZUL4
# Ativo Total                               1.57945e+07  1.39263e+07
# Ativo Circulante                          5.41742e+06  3.60527e+06
# Caixa e Equivalentes de Caixa             3.06482e+06  1.43571e+06
# Aplicações Financeiras                          91819       133548
# Contas a Receber                               998837       868541
# ...                                               ...          ...
# IR Diferido                                         0       -24554
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                     -317393 -1.22628e+06
#
#                                            30/06/2020   31/03/2020  \
# AZUL4
# Ativo Total                               1.51641e+07  1.88169e+07
# Ativo Circulante                          3.48921e+06  3.57254e+06
# Caixa e Equivalentes de Caixa             1.56637e+06       529236
# Aplicações Financeiras                          64733       738141
# Contas a Receber                               771249  1.01596e+06
# ...                                               ...          ...
# IR Diferido                                      3964       263106
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                -3.14041e+06 -6.15063e+06
#
#                                            31/12/2019   30/09/2019  \
# AZUL4
# Ativo Total                               1.91975e+07  1.86087e+07
# Ativo Circulante                          4.13873e+06  4.05577e+06
# Caixa e Equivalentes de Caixa             1.64788e+06  1.52208e+06
# Aplicações Financeiras                          62009        41053
# Contas a Receber                          1.24092e+06  1.50892e+06
# ...                                               ...          ...
# IR Diferido                                     20009         6630
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                -2.43245e+06      -453812
#
#                                            30/06/2019   31/03/2019  \
# AZUL4
# Ativo Total                                1.7736e+07  1.67421e+07
# Ativo Circulante                          3.88864e+06  3.58574e+06
# Caixa e Equivalentes de Caixa               1.213e+06       908388
# Aplicações Financeiras                         261781       396823
# Contas a Receber                          1.44866e+06   1.4173e+06
# ...                                               ...          ...
# IR Diferido                                     47374        61394
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                      345493       137678
#
#                                            31/12/2018   30/09/2018  \
# AZUL4
# Ativo Total                               1.17932e+07   1.1448e+07
# Ativo Circulante                           3.5218e+06  3.62393e+06
# Caixa e Equivalentes de Caixa                 1169136       893676
# Aplicações Financeiras                         517423       667620
# Contas a Receber                              1069056  1.34077e+06
# ...                                               ...          ...
# IR Diferido                                    -28658       -57513
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                      138169       116569
#
#                                            30/06/2018   31/03/2018  \
# AZUL4
# Ativo Total                               1.09635e+07  1.04013e+07
# Ativo Circulante                          3.42394e+06  3.10351e+06
# Caixa e Equivalentes de Caixa                  848961       738940
# Aplicações Financeiras                         725835       631620
# Contas a Receber                          1.17569e+06      1166112
# ...                                               ...          ...
# IR Diferido                                    -26217       -58216
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                      -45006       210545
#
#                                            31/12/2017   30/09/2017  \
# AZUL4
# Ativo Total                               1.03166e+07  9.00984e+06
# Ativo Circulante                          3.30434e+06      2663008
# Caixa e Equivalentes de Caixa                  762319       485864
# Aplicações Financeiras                    1.04496e+06       971655
# Contas a Receber                               914428       810032
# ...                                               ...          ...
# IR Diferido                                    -70705         1983
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                      303657       204032
#
#                                            30/06/2017   31/03/2017  \
# AZUL4
# Ativo Total                                9.1843e+06  8.06952e+06
# Ativo Circulante                          2.63974e+06  1.69554e+06
# Caixa e Equivalentes de Caixa                  500914       434970
# Aplicações Financeiras                         973243       284685
# Contas a Receber                               778632       622469
# ...                                               ...          ...
# IR Diferido                                     10709       -13667
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                      -33947        55297
#
#                                            31/12/2016
# AZUL4
# Ativo Total                               8.40041e+06
# Ativo Circulante                          1.91033e+06
# Caixa e Equivalentes de Caixa                  549164
# Aplicações Financeiras                         384616
# Contas a Receber                               673275
# ...                                               ...
# IR Diferido                                       NaN
# Participações/Contribuições Estatutárias          NaN
# Reversão dos Juros sobre Capital Próprio          NaN
# Part. de Acionistas Não Controladores             NaN
# Lucro/Prejuízo do Período                         NaN
#
# [79 rows x 17 columns], 'B3SA3': 0                                          31/12/2020   30/09/2020  \
# B3SA3
# Ativo Total                               4.63328e+07  4.53784e+07
# Ativo Circulante                          1.71013e+07  1.61274e+07
# Caixa e Equivalentes de Caixa             1.43842e+06  1.29033e+06
# Aplicações Financeiras                    1.40689e+07   1.3346e+07
# Contas a Receber                               412116       345905
# ...                                               ...          ...
# IR Diferido                                   -267798      -274450
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores              41          488
# Lucro/Prejuízo do Período                 1.09738e+06  1.13698e+06
#
# 0                                          30/06/2020   31/03/2020  \
# B3SA3
# Ativo Total                               4.41926e+07  4.11418e+07
# Ativo Circulante                          1.51399e+07  1.18813e+07
# Caixa e Equivalentes de Caixa                  966702       905064
# Aplicações Financeiras                    1.30716e+07  1.00706e+07
# Contas a Receber                               333666       312402
# ...                                               ...          ...
# IR Diferido                                   -126873       -62163
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores             629          431
# Lucro/Prejuízo do Período                      892388      1025552
#
# 0                                          31/12/2019   30/09/2019  \
# B3SA3
# Ativo Total                               4.00273e+07  4.09509e+07
# Ativo Circulante                           1.0469e+07  1.15095e+07
# Caixa e Equivalentes de Caixa                  494033       642589
# Aplicações Financeiras                      8.977e+06  1.00509e+07
# Contas a Receber                               339320       294647
# ...                                               ...          ...
# IR Diferido                                   -143146       -55836
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores             438          224
# Lucro/Prejuízo do Período                      733369       719830
#
# 0                                          30/06/2019   31/03/2019  \
# B3SA3
# Ativo Total                               4.01749e+07  3.87142e+07
# Ativo Circulante                           1.0323e+07  8.80033e+06
# Caixa e Equivalentes de Caixa                  520253       888531
# Aplicações Financeiras                     8.9685e+06  7.14921e+06
# Contas a Receber                               345388       317457
# ...                                               ...          ...
# IR Diferido                                   -109677      -123640
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores             219           81
# Lucro/Prejuízo do Período                      654769       606198
#
# 0                                          31/12/2018   30/09/2018  ...  \
# B3SA3                                                               ...
# Ativo Total                               3.76722e+07  3.86536e+07  ...
# Ativo Circulante                          7.47562e+06  8.63012e+06  ...
# Caixa e Equivalentes de Caixa                  329687       566166  ...
# Aplicações Financeiras                    6.51243e+06  7.42013e+06  ...
# Contas a Receber                               323822       287230  ...
# ...                                               ...          ...  ...
# IR Diferido                                   -123831       -25744  ...
# Participações/Contribuições Estatutárias          NaN          NaN  ...
# Reversão dos Juros sobre Capital Próprio          NaN          NaN  ...
# Part. de Acionistas Não Controladores             -80          -42  ...
# Lucro/Prejuízo do Período                      582922       465364  ...
#
# 0                                          31/12/2012   30/09/2012  \
# B3SA3
# Ativo Total                               2.41471e+07  2.41336e+07
# Ativo Circulante                          3.53628e+06  3.69387e+06
# Caixa e Equivalentes de Caixa                   43642        46276
# Aplicações Financeiras                    3.23336e+06  3.42572e+06
# Contas a Receber                                56849        58482
# ...                                               ...          ...
# IR Diferido                                   -107646      -135127
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores             122         -178
# Lucro/Prejuízo do Período                      217306       276476
#
# 0                                          30/06/2012   31/03/2012  \
# B3SA3
# Ativo Total                               2.42612e+07  2.33972e+07
# Ativo Circulante                          3.49849e+06  2.80668e+06
# Caixa e Equivalentes de Caixa                   47058        34329
# Aplicações Financeiras                    3.18063e+06  2.53329e+06
# Contas a Receber                                55029        52228
# ...                                               ...          ...
# IR Diferido                                   -135350      -140098
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores              85            5
# Lucro/Prejuízo do Período                      300082       280426
#
# 0                                          31/12/2011   30/09/2011  \
# B3SA3
# Ativo Total                               2.35899e+07   2.3145e+07
# Ativo Circulante                          2.40113e+06  2.19837e+06
# Caixa e Equivalentes de Caixa                   64648       139477
# Aplicações Financeiras                    2.12871e+06  1.86184e+06
# Contas a Receber                                46514        65440
# ...                                               ...          ...
# IR Diferido                                   -138286      -142179
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores             -50           76
# Lucro/Prejuízo do Período                      191066       292006
#
# 0                                          30/06/2011   31/03/2011  \
# B3SA3
# Ativo Total                                2.2564e+07  2.40323e+07
# Ativo Circulante                           2.2097e+06   3.7798e+06
# Caixa e Equivalentes de Caixa                   25097   1.5423e+06
# Aplicações Financeiras                    1.98041e+06  2.03143e+06
# Contas a Receber                                71374        67326
# ...                                               ...          ...
# IR Diferido                                    -98627      -111167
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores             -19         -537
# Lucro/Prejuízo do Período                      294171       270756
#
# 0                                          31/12/2010   30/09/2010
# B3SA3
# Ativo Total                                2.2634e+07  2.27717e+07
# Ativo Circulante                          2.54759e+06   3.1316e+06
# Caixa e Equivalentes de Caixa                  104017  2.96068e+06
# Aplicações Financeiras                    2.26441e+06            0
# Contas a Receber                                51399       142881
# ...                                               ...          ...
# IR Diferido                                   -106714      -125761
# Participações/Contribuições Estatutárias          NaN            0
# Reversão dos Juros sobre Capital Próprio          NaN            0
# Part. de Acionistas Não Controladores              75            0
# Lucro/Prejuízo do Período                      261918       293208
#
# [79 rows x 42 columns], 'BBAS3': 0                                          31/12/2020   30/09/2020  \
# BBAS3
# Ativo Total                               1.78254e+09  1.83977e+09
# Ativo Circulante                                    0  1.00204e+09
# Disponibilidades                                    0  1.70473e+07
# Aplicações Interfinanceiras de Liquidez             0  6.01446e+08
# Títulos e Valores Mobiliários                       0  4.73987e+07
# ...                                               ...          ...
# IR Diferido                                       NaN       872712
# Participações/Contribuições Estatutárias      -339488      -397328
# Reversão dos Juros sobre Capital Próprio          NaN            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 3.12682e+06  3.03748e+06
#
# 0                                          30/06/2020   31/03/2020  \
# BBAS3
# Ativo Total                               1.78047e+09  1.66354e+09
# Ativo Circulante                          9.35725e+08  8.96516e+08
# Disponibilidades                          2.10493e+07  1.33813e+07
# Aplicações Interfinanceiras de Liquidez   5.34901e+08   5.2124e+08
# Títulos e Valores Mobiliários             3.78411e+07  3.76425e+07
# ...                                               ...          ...
# IR Diferido                                    915909   3.5957e+06
# Participações/Contribuições Estatutárias      -412427      -413097
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 3.15858e+06  3.18928e+06
#
# 0                                          31/12/2019   30/09/2019  \
# BBAS3
# Ativo Total                               1.53889e+09  1.56854e+09
# Ativo Circulante                          8.00328e+08  8.85086e+08
# Disponibilidades                             1.28e+07  1.27345e+07
# Aplicações Interfinanceiras de Liquidez   4.40275e+08   4.7442e+08
# Títulos e Valores Mobiliários             3.48411e+07  3.86454e+07
# ...                                               ...          ...
# IR Diferido                               8.14711e+06  2.08463e+06
# Participações/Contribuições Estatutárias      -732057      -549814
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 5.61774e+06  4.16174e+06
#
# 0                                          30/06/2019   31/03/2019  \
# BBAS3
# Ativo Total                                1.6018e+09  1.57931e+09
# Ativo Circulante                           9.3082e+08  9.46762e+08
# Disponibilidades                          1.22093e+07  1.64751e+07
# Aplicações Interfinanceiras de Liquidez   5.31087e+08    5.264e+08
# Títulos e Valores Mobiliários             2.61801e+07  2.54546e+07
# ...                                               ...          ...
# IR Diferido                               2.20077e+06       466798
# Participações/Contribuições Estatutárias      -533323      -514519
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 4.20235e+06  3.91752e+06
#
# 0                                          31/12/2018   30/09/2018  ...  \
# BBAS3                                                               ...
# Ativo Total                               1.47938e+09  1.53926e+09  ...
# Ativo Circulante                          8.27644e+08    841940992  ...
# Disponibilidades                          1.24852e+07  1.16839e+07  ...
# Aplicações Interfinanceiras de Liquidez   4.20833e+08  4.42201e+08  ...
# Títulos e Valores Mobiliários             1.79179e+07  1.64397e+07  ...
# ...                                               ...          ...  ...
# IR Diferido                              -1.73491e+06        26464  ...
# Participações/Contribuições Estatutárias      -482054      -407098  ...
# Reversão dos Juros sobre Capital Próprio            0            0  ...
# Part. de Acionistas Não Controladores             NaN          NaN  ...
# Lucro/Prejuízo do Período                 3.72136e+06  3.09233e+06  ...
#
# 0                                          31/12/2012   30/09/2012  \
# BBAS3
# Ativo Total                               1.04928e+09  1.00992e+09
# Ativo Circulante                           5.8582e+08  5.82005e+08
# Disponibilidades                          1.11891e+07  1.36037e+07
# Aplicações Interfinanceiras de Liquidez    2.2011e+08  2.20037e+08
# Títulos e Valores Mobiliários             3.82579e+07   3.8909e+07
# ...                                               ...          ...
# IR Diferido                                   -824675  1.16467e+06
# Participações/Contribuições Estatutárias      -511138      -358466
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                  3.9494e+06  2.80453e+06
#
# 0                                          30/06/2012   31/03/2012  \
# BBAS3
# Ativo Total                               9.62761e+08  9.13867e+08
# Ativo Circulante                          5.54627e+08  5.45373e+08
# Disponibilidades                          1.62871e+07  1.42656e+07
# Aplicações Interfinanceiras de Liquidez   1.93079e+08  1.80626e+08
# Títulos e Valores Mobiliários             3.38901e+07  3.12419e+07
# ...                                               ...          ...
# IR Diferido                                    437647  1.23748e+06
# Participações/Contribuições Estatutárias      -383390      -326693
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 3.00151e+06  2.55443e+06
#
# 0                                          31/12/2011   30/09/2011  \
# BBAS3
# Ativo Total                               8.90352e+08   8.5928e+08
# Ativo Circulante                          5.18717e+08  5.12078e+08
# Disponibilidades                          9.22722e+06  1.97674e+07
# Aplicações Interfinanceiras de Liquidez   1.60956e+08  1.53334e+08
# Títulos e Valores Mobiliários             3.85957e+07  4.11259e+07
# ...                                               ...          ...
# IR Diferido                              -1.21717e+06  1.31336e+06
# Participações/Contribuições Estatutárias      -395019      -369039
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 3.09368e+06  2.89128e+06
#
# 0                                          30/06/2011   31/03/2011  \
# BBAS3
# Ativo Total                               8.16131e+08  7.87908e+08
# Ativo Circulante                          4.79955e+08  4.60671e+08
# Disponibilidades                          1.88684e+07  1.22441e+07
# Aplicações Interfinanceiras de Liquidez   1.45592e+08    1.454e+08
# Títulos e Valores Mobiliários             3.53132e+07  3.34822e+07
# ...                                               ...          ...
# IR Diferido                                     71272       469621
# Participações/Contribuições Estatutárias      -425091      -374012
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                    3.33e+06  2.93236e+06
#
# 0                                          31/12/2010   30/09/2010
# BBAS3
# Ativo Total                               7.37497e+08  7.22986e+08
# Ativo Circulante                          4.23727e+08   4.0547e+08
# Disponibilidades                          9.39725e+06  9.29161e+06
# Aplicações Interfinanceiras de Liquidez   1.09929e+08  1.33051e+08
# Títulos e Valores Mobiliários             4.07224e+07  2.75083e+07
# ...                                               ...          ...
# IR Diferido                                    173532            0
# Participações/Contribuições Estatutárias      -509578      -335071
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN            0
# Lucro/Prejuízo do Período                 4.00215e+06  2.62476e+06
#
# [78 rows x 42 columns], 'BBDC4': 0                                          31/12/2020   30/09/2020  \
# BBDC4
# Ativo Total                               1.37214e+09  1.41019e+09
# Ativo Circulante                                    0            0
# Disponibilidades                                    0            0
# Aplicações Interfinanceiras de Liquidez             0            0
# Títulos e Valores Mobiliários                       0            0
# ...                                               ...          ...
# IR Diferido                                       NaN          NaN
# Participações/Contribuições Estatutárias            0            0
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 5.46436e+06      4194080
#
# 0                                          30/06/2020   31/03/2020  \
# BBDC4
# Ativo Total                               1.32952e+09  1.24026e+09
# Ativo Circulante                          6.74138e+08  6.01132e+08
# Disponibilidades                          2.06849e+07  2.20164e+07
# Aplicações Interfinanceiras de Liquidez   1.89114e+08  1.20079e+08
# Títulos e Valores Mobiliários             1.00438e+08  1.01038e+08
# ...                                               ...          ...
# IR Diferido                                         0            0
# Participações/Contribuições Estatutárias            0            0
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 3.50605e+06  3.38209e+06
#
# 0                                          31/12/2019   30/09/2019  \
# BBDC4
# Ativo Total                               1.14703e+09  1.14322e+09
# Ativo Circulante                          5.72182e+08  5.81536e+08
# Disponibilidades                          1.81877e+07  1.55259e+07
# Aplicações Interfinanceiras de Liquidez   7.78235e+07     95805440
# Títulos e Valores Mobiliários             1.26978e+08  1.19705e+08
# ...                                               ...          ...
# IR Diferido                                         0            0
# Participações/Contribuições Estatutárias            0            0
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 4.88312e+06  5.83697e+06
#
# 0                                          30/06/2019   31/03/2019  \
# BBDC4
# Ativo Total                               1.13266e+09   1.1176e+09
# Ativo Circulante                          6.02771e+08  5.86285e+08
# Disponibilidades                          1.42756e+07  1.70283e+07
# Aplicações Interfinanceiras de Liquidez   1.60838e+08  1.75108e+08
# Títulos e Valores Mobiliários             1.25734e+08  9.77166e+07
# ...                                               ...          ...
# IR Diferido                                         0            0
# Participações/Contribuições Estatutárias            0            0
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 6.04208e+06  5.82044e+06
#
# 0                                          31/12/2018   30/09/2018  ...  \
# BBDC4                                                               ...
# Ativo Total                                1.1122e+09  1.09058e+09  ...
# Ativo Circulante                          5.92819e+08  5.84814e+08  ...
# Disponibilidades                          1.89311e+07  1.43341e+07  ...
# Aplicações Interfinanceiras de Liquidez   1.90849e+08  1.79151e+08  ...
# Títulos e Valores Mobiliários             1.15617e+08  1.28866e+08  ...
# ...                                               ...          ...  ...
# IR Diferido                                         0            0  ...
# Participações/Contribuições Estatutárias            0            0  ...
# Reversão dos Juros sobre Capital Próprio            0            0  ...
# Part. de Acionistas Não Controladores             NaN          NaN  ...
# Lucro/Prejuízo do Período                 5.08077e+06  5.00968e+06  ...
#
# 0                                          31/12/2012   30/09/2012  \
# BBDC4
# Ativo Total                               8.44402e+08  7.93564e+08
# Ativo Circulante                          5.22864e+08  5.06422e+08
# Disponibilidades                          1.14362e+07  1.17821e+07
# Aplicações Interfinanceiras de Liquidez   1.87863e+08   1.4743e+08
# Títulos e Valores Mobiliários             1.42859e+08  1.61144e+08
# ...                                               ...          ...
# IR Diferido                                         0            0
# Participações/Contribuições Estatutárias            0            0
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 2.89336e+06  2.86238e+06
#
# 0                                          30/06/2012   31/03/2012  \
# BBDC4
# Ativo Total                                 7.877e+08  7.58679e+08
# Ativo Circulante                          4.81205e+08  4.60013e+08
# Disponibilidades                          1.32827e+07  2.43212e+07
# Aplicações Interfinanceiras de Liquidez   1.11814e+08    103398400
# Títulos e Valores Mobiliários             1.57109e+08   1.4464e+08
# ...                                               ...          ...
# IR Diferido                                         0            0
# Participações/Contribuições Estatutárias            0            0
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 2.83297e+06  2.79254e+06
#
# 0                                          31/12/2011   30/09/2011  \
# BBDC4
# Ativo Total                               7.53337e+08  7.24325e+08
# Ativo Circulante                          5.02029e+08  4.60418e+08
# Disponibilidades                          2.19458e+07  9.65514e+06
# Aplicações Interfinanceiras de Liquidez    1.0168e+08  1.05074e+08
# Títulos e Valores Mobiliários             1.84744e+08  1.45348e+08
# ...                                               ...          ...
# IR Diferido                                         0            0
# Participações/Contribuições Estatutárias            0            0
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 2.72568e+06  2.81515e+06
#
# 0                                          30/06/2011   31/03/2011  \
# BBDC4
# Ativo Total                               6.91781e+08    6.749e+08
# Ativo Circulante                          4.41144e+08  4.35994e+08
# Disponibilidades                          7.39366e+06  6.55136e+06
# Aplicações Interfinanceiras de Liquidez   1.04617e+08  1.18197e+08
# Títulos e Valores Mobiliários             1.41016e+08  1.25846e+08
# ...                                               ...          ...
# IR Diferido                                         0            0
# Participações/Contribuições Estatutárias            0            0
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                 2.78539e+06  2.70204e+06
#
# 0                                          31/12/2010   30/09/2010
# BBDC4
# Ativo Total                               6.35081e+08   6.2061e+08
# Ativo Circulante                          3.91178e+08   3.9061e+08
# Disponibilidades                           1.5583e+07  9.41986e+06
# Aplicações Interfinanceiras de Liquidez   9.07915e+07  1.09645e+08
# Títulos e Valores Mobiliários             1.12573e+08   1.0475e+08
# ...                                               ...          ...
# IR Diferido                                         0            0
# Participações/Contribuições Estatutárias            0            0
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores             NaN       -63310
# Lucro/Prejuízo do Período                 2.98674e+06   2.5269e+06
#
# [78 rows x 42 columns], 'BBSE3':                                            31/03/2014   31/12/2013  \
# BBSE3
# Ativo Total                               8.28299e+06  8.78548e+06
# Ativo Circulante                          1.89715e+06  2.55805e+06
# Caixa e Equivalentes de Caixa             1.15377e+06  1.78528e+06
# Aplicações Financeiras                           3121         3046
# Contas a Receber                                    0            0
# ...                                               ...          ...
# IR Diferido                                         0            0
# Participações/Contribuições Estatutárias            0            0
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                           0            0
#
#                                            30/09/2013   30/06/2013  \
# BBSE3
# Ativo Total                               7.82638e+06  8.35234e+06
# Ativo Circulante                          1.70758e+06  2.47222e+06
# Caixa e Equivalentes de Caixa             1.01493e+06  1.67543e+06
# Aplicações Financeiras                           3016          393
# Contas a Receber                                    0            0
# ...                                               ...          ...
# IR Diferido                                         0            0
# Participações/Contribuições Estatutárias            0            0
# Reversão dos Juros sobre Capital Próprio            0            0
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                           0            0
#
#                                            31/03/2013   31/12/2012  NaN
# BBSE3
# Ativo Total                               7.57307e+06  7.29261e+06  NaN
# Ativo Circulante                          2.00207e+06  1.90131e+06  NaN
# Caixa e Equivalentes de Caixa             1.38257e+06  1.32793e+06  NaN
# Aplicações Financeiras                            375          398  NaN
# Contas a Receber                                    0            0  NaN
# ...                                               ...          ...  ...
# IR Diferido                                         0          NaN  NaN
# Participações/Contribuições Estatutárias            0          NaN  0.0
# Reversão dos Juros sobre Capital Próprio            0          NaN  0.0
# Part. de Acionistas Não Controladores               0          NaN  0.0
# Lucro/Prejuízo do Período                           0          NaN  0.0
#
# [79 rows x 7 columns], 'BEEF3': 0                                          31/12/2020   30/09/2020  \
# BEEF3
# Ativo Total                               1.69233e+07  1.81007e+07
# Ativo Circulante                          1.12863e+07  1.24087e+07
# Caixa e Equivalentes de Caixa             4.78834e+06  5.03966e+06
# ...
# Part. de Acionistas Não Controladores          -12142       -13952
# Lucro/Prejuízo do Período                      514375       440023
#
# 0                                          31/12/2019   30/09/2019  \
# WEGE3
# Ativo Total                               1.56876e+07  1.54794e+07
# Ativo Circulante                           9.7609e+06  9.64984e+06
# Caixa e Equivalentes de Caixa             1.94604e+06   2.1004e+06
# Aplicações Financeiras                    1.44423e+06  1.33568e+06
# Contas a Receber                          2.74708e+06  2.48867e+06
# ...                                               ...          ...
# IR Diferido                                     18184         7319
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores           -3961        -6297
# Lucro/Prejuízo do Período                      500487       418243
#
# 0                                          30/06/2019   31/03/2019  \
# WEGE3
# Ativo Total                               1.49078e+07   1.5227e+07
# Ativo Circulante                          8.80348e+06  9.08984e+06
# Caixa e Equivalentes de Caixa             1.84387e+06  1.96751e+06
# Aplicações Financeiras                         938886       925042
# Contas a Receber                              2474176  2.42947e+06
# ...                                               ...          ...
# IR Diferido                                     13061         6538
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores           -6258        -1358
# Lucro/Prejuízo do Período                      389002       306849
#
# 0                                          31/12/2018   30/09/2018  ...  \
# WEGE3                                                               ...
# Ativo Total                               1.53998e+07  1.62741e+07  ...
# Ativo Circulante                          9.43858e+06  1.00751e+07  ...
# Caixa e Equivalentes de Caixa              2.2057e+06  1.81872e+06  ...
# Aplicações Financeiras                    1.32419e+06  2.11915e+06  ...
# Contas a Receber                          2.44084e+06      2564768  ...
# ...                                               ...          ...  ...
# IR Diferido                                      1892        22489  ...
# Participações/Contribuições Estatutárias          NaN          NaN  ...
# Reversão dos Juros sobre Capital Próprio          NaN          NaN  ...
# Part. de Acionistas Não Controladores           -1572         1318  ...
# Lucro/Prejuízo do Período                      335280       381430  ...
#
# 0                                          31/12/2012   30/09/2012  \
# WEGE3
# Ativo Total                               8.87355e+06  8.75703e+06
# Ativo Circulante                          5.71002e+06  5.65702e+06
# Caixa e Equivalentes de Caixa             2.30226e+06  2.26823e+06
# Aplicações Financeiras                         261244       256634
# Contas a Receber                          1.47284e+06  1.41175e+06
# ...                                               ...          ...
# IR Diferido                                      8620         6141
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores           -1651        -2190
# Lucro/Prejuízo do Período                      183157       184756
#
# 0                                          30/06/2012   31/03/2012  \
# WEGE3
# Ativo Total                                9.1097e+06  8.82412e+06
# Ativo Circulante                          6.02012e+06  5.47885e+06
# Caixa e Equivalentes de Caixa             2.62694e+06  2.56389e+06
# Aplicações Financeiras                         251540            0
# Contas a Receber                          1.35025e+06  1.26396e+06
# ...                                               ...          ...
# IR Diferido                                      9695         5165
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores           -2016        -3028
# Lucro/Prejuízo do Período                      139819       148247
#
# 0                                          31/12/2011   30/09/2011  \
# WEGE3
# Ativo Total                               9.10586e+06  8.69583e+06
# Ativo Circulante                          5.86706e+06  5.74201e+06
# Caixa e Equivalentes de Caixa                   59512  3.08657e+06
# Aplicações Financeiras                     2.8721e+06            0
# Contas a Receber                          1.30769e+06  1.16206e+06
# ...                                               ...          ...
# IR Diferido                                     -1713        12225
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores           -7532        -5623
# Lucro/Prejuízo do Período                      156248       154567
#
# 0                                          30/06/2011   31/03/2011  \
# WEGE3
# Ativo Total                               7.97951e+06  7.42439e+06
# Ativo Circulante                          5.06959e+06  4.73186e+06
# Caixa e Equivalentes de Caixa             2.67464e+06      2487136
# Aplicações Financeiras                              0            0
# Contas a Receber                          1.09585e+06  1.02609e+06
# ...                                               ...          ...
# IR Diferido                                     10859         2480
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores           -4235        -2695
# Lucro/Prejuízo do Período                      154557       121564
#
# 0                                          31/12/2010   30/09/2010
# WEGE3
# Ativo Total                               7.51116e+06  7.36511e+06
# Ativo Circulante                          4.79401e+06  4.62828e+06
# Caixa e Equivalentes de Caixa                   53971  2.39977e+06
# Aplicações Financeiras                    2.49902e+06            0
# Contas a Receber                              1044712  1.02665e+06
# ...                                               ...          ...
# IR Diferido                                    -14654        -6942
# Participações/Contribuições Estatutárias          NaN         -860
# Reversão dos Juros sobre Capital Próprio          NaN        34347
# Part. de Acionistas Não Controladores           -5292        -7312
# Lucro/Prejuízo do Período                      141508       142107
#
# [79 rows x 42 columns], 'YDUQ3': 0                                          31/12/2020   30/09/2020  \
# YDUQ3
# Ativo Total                               9.26527e+06    9.411e+06
# Ativo Circulante                           2.7364e+06  2.99412e+06
# Caixa e Equivalentes de Caixa                   28407        25176
# Aplicações Financeiras                    1.60487e+06  1.89539e+06
# Contas a Receber                               890151       873301
# ...                                               ...          ...
# IR Diferido                                     37923        17439
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                     -102641       112476
#
# 0                                          30/06/2020   31/03/2020  \
# YDUQ3
# Ativo Total                                9.2943e+06   7.6358e+06
# Ativo Circulante                          3.04721e+06  3.33201e+06
# Caixa e Equivalentes de Caixa                   20415        10392
# Aplicações Financeiras                    1.88696e+06      2535168
# Contas a Receber                               955828       641709
# ...                                               ...          ...
# IR Diferido                                     49837        27825
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                      -79542       167888
#
# 0                                          31/12/2019   30/09/2019  \
# YDUQ3
# Ativo Total                               5.51249e+06  5.74026e+06
# Ativo Circulante                          1.47568e+06  1.66454e+06
# Caixa e Equivalentes de Caixa                   12251        10071
# Aplicações Financeiras                         596861       855699
# Contas a Receber                               759622       714601
# ...                                               ...          ...
# IR Diferido                                     -5763        13165
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                       58059       152511
#
# 0                                          30/06/2019   31/03/2019  \
# YDUQ3
# Ativo Total                               5.56419e+06  5.65275e+06
# Ativo Circulante                          1.61894e+06  1.74949e+06
# Caixa e Equivalentes de Caixa                   19436         8695
# Aplicações Financeiras                         698840       877087
# Contas a Receber                               813103       712993
# ...                                               ...          ...
# IR Diferido                                     -7007        37620
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                      194773       240797
#
# 0                                          31/12/2018   30/09/2018  ...  \
# YDUQ3                                                               ...
# Ativo Total                               4.10246e+06  4.20166e+06  ...
# Ativo Circulante                          1.55063e+06  1.63213e+06  ...
# Caixa e Equivalentes de Caixa                   13686         8612  ...
# Aplicações Financeiras                         804360       761982  ...
# Contas a Receber                               571854       704052  ...
# ...                                               ...          ...  ...
# IR Diferido                                    -40525        24064  ...
# Participações/Contribuições Estatutárias          NaN          NaN  ...
# Reversão dos Juros sobre Capital Próprio          NaN          NaN  ...
# Part. de Acionistas Não Controladores               0            0  ...
# Lucro/Prejuízo do Período                       16301       194321  ...
#
# 0                                          31/12/2012  30/09/2012 30/06/2012  \
# YDUQ3
# Ativo Total                               1.23981e+06  1.2392e+06  1.151e+06
# Ativo Circulante                               511227      542744     520480
# Caixa e Equivalentes de Caixa                   18132       11756      17928
# Aplicações Financeiras                         122340      172014     149733
# Contas a Receber                               279657      358974     352819
# ...                                               ...         ...        ...
# IR Diferido                                      -246        -413      -1785
# Participações/Contribuições Estatutárias          NaN         NaN        NaN
# Reversão dos Juros sobre Capital Próprio          NaN         NaN        NaN
# Part. de Acionistas Não Controladores               0           0          0
# Lucro/Prejuízo do Período                       14899       39807      15064
#
# 0                                        31/03/2012   31/12/2011 30/09/2011  \
# YDUQ3
# Ativo Total                               1.137e+06  1.06872e+06     900470
# Ativo Circulante                             545145       497708     355178
# Caixa e Equivalentes de Caixa                  6690        21857      53679
# Aplicações Financeiras                       176033       147565       8668
# Contas a Receber                             362422       328286     292831
# ...                                             ...          ...        ...
# IR Diferido                                     948        -2326       2559
# Participações/Contribuições Estatutárias        NaN          NaN        NaN
# Reversão dos Juros sobre Capital Próprio        NaN          NaN        NaN
# Part. de Acionistas Não Controladores             0            0          0
# Lucro/Prejuízo do Período                     39917         2390      31114
#
# 0                                        30/06/2011 31/03/2011 31/12/2010  \
# YDUQ3
# Ativo Total                                  874085     839409     804536
# Ativo Circulante                             351638     378564     390428
# Caixa e Equivalentes de Caixa                 61522      38817      44727
# Aplicações Financeiras                         6670      89354     120687
# Contas a Receber                             283446     250393     225014
# ...                                             ...        ...        ...
# IR Diferido                                   -4017          0      12968
# Participações/Contribuições Estatutárias        NaN        NaN        NaN
# Reversão dos Juros sobre Capital Próprio        NaN        NaN        NaN
# Part. de Acionistas Não Controladores             0          0          0
# Lucro/Prejuízo do Período                      7919      28732      24256
#
# 0                                        30/09/2010
# YDUQ3
# Ativo Total                                  729691
# Ativo Circulante                             367895
# Caixa e Equivalentes de Caixa                183715
# Aplicações Financeiras                            0
# Contas a Receber                             154726
# ...                                             ...
# IR Diferido                                       0
# Participações/Contribuições Estatutárias          0
# Reversão dos Juros sobre Capital Próprio          0
# Part. de Acionistas Não Controladores             0
# Lucro/Prejuízo do Período                     25073
#
# [79 rows x 42 columns]}

# %%
print(len(fundamentos))
# Out:
# 77

# %% [markdown]
# ### Pegar Preços das Ações nas Datas Correspondentes

# %%
cotacoes_df = pd.read_excel("Cotacoes.xlsx")
display(cotacoes_df)
# Out:
#              Date       High        Low       Open      Close     Volume  \
# 0      2012-12-20  17.376226  16.920275  17.352230  16.926273  1243126.0
# 1      2012-12-21  17.202246  16.808285  16.926273  16.994267  1390141.0
# 2      2012-12-26  17.090256  16.754292  17.002266  16.768290  1076609.0
# 3      2012-12-27  16.870279  16.670300  16.722294  16.778288  1307633.0
# 4      2012-12-28  16.916273  16.738293  16.858280  16.738293  2807786.0
# ...           ...        ...        ...        ...        ...        ...
# 147975 2021-04-14  32.810001  32.029999  32.599998  32.360001  1935600.0
# 147976 2021-04-15  32.759998  31.900000  32.400002  32.220001  1520200.0
# 147977 2021-04-16  32.410000  31.870001  32.180000  32.160000  2455800.0
# 147978 2021-04-19  32.220001  31.180000  32.060001  31.200001  2361800.0
# 147979 2021-04-20  31.090000  29.450001  31.000000  29.549999  4228000.0
#
#         Adj Close Empresa
# 0       12.422499   ABEV3
# 1       12.472404   ABEV3
# 2       12.306555   ABEV3
# 3       12.448023   ABEV3
# 4       12.418349   ABEV3
# ...           ...     ...
# 147975  32.360001   YDUQ3
# 147976  32.220001   YDUQ3
# 147977  32.160000   YDUQ3
# 147978  31.200001   YDUQ3
# 147979  29.549999   YDUQ3
#
# [147980 rows x 8 columns]

# %%
cotacoes_df = pd.read_excel("Cotacoes.xlsx")
cotacoes = {}
for empresa in cotacoes_df["Empresa"].unique():
    cotacoes[empresa] = cotacoes_df.loc[cotacoes_df['Empresa']==empresa, :]
display(cotacoes['ABEV3'])
# Out:
#            Date       High        Low       Open      Close      Volume  \
# 0    2012-12-20  17.376226  16.920275  17.352230  16.926273   1243126.0
# 1    2012-12-21  17.202246  16.808285  16.926273  16.994267   1390141.0
# 2    2012-12-26  17.090256  16.754292  17.002266  16.768290   1076609.0
# 3    2012-12-27  16.870279  16.670300  16.722294  16.778288   1307633.0
# 4    2012-12-28  16.916273  16.738293  16.858280  16.738293   2807786.0
# ...         ...        ...        ...        ...        ...         ...
# 2073 2021-04-14  15.900000  15.620000  15.640000  15.810000  21466700.0
# 2074 2021-04-15  16.030001  15.720000  15.790000  15.870000  17705700.0
# 2075 2021-04-16  15.960000  15.720000  15.790000  15.800000  13563400.0
# 2076 2021-04-19  16.070000  15.510000  15.540000  15.730000  20032500.0
# 2077 2021-04-20  15.800000  15.530000  15.670000  15.620000  12697600.0
#
#       Adj Close Empresa
# 0     12.422499   ABEV3
# 1     12.472404   ABEV3
# 2     12.306555   ABEV3
# 3     12.448023   ABEV3
# 4     12.418349   ABEV3
# ...         ...     ...
# 2073  15.810000   ABEV3
# 2074  15.870000   ABEV3
# 2075  15.800000   ABEV3
# 2076  15.730000   ABEV3
# 2077  15.620000   ABEV3
#
# [2078 rows x 8 columns]

# %%
display(fundamentos['ABEV3'])
# Out:
#                                            31/12/2020   30/09/2020  \
# ABEV3
# Ativo Total                               1.25197e+08  1.27057e+08
# Ativo Circulante                          3.53426e+07  3.90988e+07
# Caixa e Equivalentes de Caixa             1.70903e+07  2.16605e+07
# Aplicações Financeiras                    1.70003e+06  1.44292e+06
# Contas a Receber                          4.30314e+06  4.15692e+06
# ...                                               ...          ...
# IR Diferido                              -1.66758e+06       343476
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores         -104363       -84167
# Lucro/Prejuízo do Período                 6.78601e+06   2.2748e+06
#
#                                            30/06/2020   31/03/2020  \
# ABEV3
# Ativo Total                               1.21393e+08  1.13688e+08
# Ativo Circulante                          3.62681e+07  3.10864e+07
# Caixa e Equivalentes de Caixa              1.7439e+07  1.32045e+07
# Aplicações Financeiras                          44823        44823
# Contas a Receber                          4.20158e+06   3.3943e+06
# ...                                               ...          ...
# IR Diferido                                    595088        15365
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores          -44517      -119468
# Lucro/Prejuízo do Período                  1.2268e+06  1.09178e+06
#
#                                            31/12/2019   30/09/2019  \
# ABEV3
# Ativo Total                               1.01743e+08  1.02475e+08
# Ativo Circulante                          2.76211e+07   2.9004e+07
# Caixa e Equivalentes de Caixa             1.19007e+07  1.50169e+07
# Aplicações Financeiras                          14558        14304
# Contas a Receber                          4.49552e+06  4.23626e+06
# ...                                               ...          ...
# IR Diferido                                   -853995       427238
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores         -119273      -106708
# Lucro/Prejuízo do Período                  4.0997e+06  2.49768e+06
#
#                                            30/06/2019   31/03/2019  \
# ABEV3
# Ativo Total                                9.8739e+07  9.69055e+07
# Ativo Circulante                           2.7356e+07  2.61941e+07
# Caixa e Equivalentes de Caixa             1.42334e+07  1.28225e+07
# Aplicações Financeiras                          14038        13772
# Contas a Receber                          4.10312e+06  3.98036e+06
# ...                                               ...          ...
# IR Diferido                                    443414       346724
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores          -95168       -87218
# Lucro/Prejuízo do Período                 2.52073e+06  2.66185e+06
#
#                                            31/12/2018   30/09/2018  ...  \
# ABEV3                                                               ...
# Ativo Total                               9.41261e+07   9.5691e+07  ...
# Ativo Circulante                          2.53296e+07     2.62e+07  ...
# Caixa e Equivalentes de Caixa             1.14635e+07  1.22277e+07  ...
# Aplicações Financeiras                          13391        13008  ...
# Contas a Receber                          4.87926e+06  4.28563e+06  ...
# ...                                               ...          ...  ...
# IR Diferido                              -1.16093e+06       612890  ...
# Participações/Contribuições Estatutárias          NaN          NaN  ...
# Reversão dos Juros sobre Capital Próprio          NaN          NaN  ...
# Part. de Acionistas Não Controladores         -103126       -60947  ...
# Lucro/Prejuízo do Período                  3.3604e+06  2.83116e+06  ...
#
#                                            31/03/2015   31/12/2014  \
# ABEV3
# Ativo Total                                  75101184  7.21432e+07
# Ativo Circulante                           1.9241e+07  2.07284e+07
# Caixa e Equivalentes de Caixa             6.97458e+06  9.72207e+06
# Aplicações Financeiras                    1.03376e+06       712958
# Contas a Receber                           2.8977e+06  3.02885e+06
# ...                                               ...          ...
# IR Diferido                                    -28029      -859414
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores         -152180      -120675
# Lucro/Prejuízo do Período                 2.81066e+06  4.53839e+06
#
#                                            30/09/2014   30/06/2014  \
# ABEV3
# Ativo Total                               6.51259e+07   6.2989e+07
# Ativo Circulante                          1.54466e+07  1.57733e+07
# Caixa e Equivalentes de Caixa             5.74812e+06  6.27386e+06
# Aplicações Financeiras                         526789       379938
# Contas a Receber                          3.27564e+06  3.53838e+06
# ...                                               ...          ...
# IR Diferido                                    475888        30916
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores          -76946       -48724
# Lucro/Prejuízo do Período                  2.8136e+06  2.16688e+06
#
#                                            31/03/2014   31/12/2013  \
# ABEV3
# Ativo Total                                6.3297e+07   6.8674e+07
# Ativo Circulante                          1.63523e+07    2.047e+07
# Caixa e Equivalentes de Caixa             7.29618e+06  1.12858e+07
# Aplicações Financeiras                         410173       288604
# Contas a Receber                          3.11009e+06  3.61351e+06
# ...                                               ...          ...
# IR Diferido                                    403236      -197098
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores          -50162     -85133.1
# Lucro/Prejuízo do Período                 2.54664e+06  6.09375e+06
#
#                                            30/09/2013   30/06/2013  \
# ABEV3
# Ativo Total                                5.9619e+07  5.87393e+07
# Ativo Circulante                          1.24784e+07  1.20571e+07
# Caixa e Equivalentes de Caixa             4.83517e+06  4.48217e+06
# Aplicações Financeiras                         612489       486133
# Contas a Receber                          2.74785e+06  2.78314e+06
# ...                                               ...          ...
# IR Diferido                                   -462300       114066
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores          -49296      -758399
# Lucro/Prejuízo do Período                 2.28971e+06  1.14174e+06
#
#                                            31/03/2013  31/12/2012
# ABEV3
# Ativo Total                               1.34037e+06  1.3463e+06
# Ativo Circulante                                77552       71641
# Caixa e Equivalentes de Caixa                   74204       48155
# Aplicações Financeiras                              0           0
# Contas a Receber                                 3105       21490
# ...                                               ...         ...
# IR Diferido                                       -70         NaN
# Participações/Contribuições Estatutárias          NaN         NaN
# Reversão dos Juros sobre Capital Próprio          NaN         NaN
# Part. de Acionistas Não Controladores             NaN         NaN
# Lucro/Prejuízo do Período                        9768         NaN
#
# [79 rows x 33 columns]

# %% [markdown]
# ### Remover empresas que tem cotações vazias da análise (mesmo após o tratamento que fizemos na hora de pegar as cotações)

# %%
for empresa in empresas:
    if cotacoes[empresa].isnull().values.any():
        cotacoes.pop(empresa)
        fundamentos.pop(empresa)
empresas = list(cotacoes.keys())
print(len(empresas))
# Out:
# 65

# %% [markdown]
# ### Juntar fundamentos com Preço da Ação

# %%
# no cotacoes: jogar as datas para índice
# no fundamnetos:
    # trocar linhas por colunas
    # tratar as datas para formato de data do python
    # juntar os fundamentos com a coluna Adj Close das cotacoes
for empresa in fundamentos:
    tabela = fundamentos[empresa].T
    tabela.index = pd.to_datetime(tabela.index, format="%d/%m/%Y")
    tabela_cotacao = cotacoes[empresa].set_index("Date")
    tabela_cotacao = tabela_cotacao[["Adj Close"]]
    
    tabela = tabela.merge(tabela_cotacao, right_index=True, left_index=True)
    tabela.index.name = empresa
    fundamentos[empresa] = tabela
display(fundamentos["ABEV3"])
# Out:
#             Ativo Total Ativo Circulante Caixa e Equivalentes de Caixa  \
# ABEV3
# 2020-12-31  1.25197e+08      3.53426e+07                   1.70903e+07
# 2020-09-30  1.27057e+08      3.90988e+07                   2.16605e+07
# 2020-06-30  1.21393e+08      3.62681e+07                    1.7439e+07
# 2020-03-31  1.13688e+08      3.10864e+07                   1.32045e+07
# 2019-12-31  1.01743e+08      2.76211e+07                   1.19007e+07
# 2019-09-30  1.02475e+08       2.9004e+07                   1.50169e+07
# 2019-06-30   9.8739e+07       2.7356e+07                   1.42334e+07
# 2019-03-31  9.69055e+07      2.61941e+07                   1.28225e+07
# 2018-12-31  9.41261e+07      2.53296e+07                   1.14635e+07
# 2018-09-30   9.5691e+07         2.62e+07                   1.22277e+07
# 2018-06-30  9.09214e+07      2.64091e+07                     1.062e+07
# 2018-03-31  8.23789e+07      2.15606e+07                   7.95348e+06
# 2017-12-31   8.6852e+07      2.47181e+07                   1.03545e+07
# 2017-09-30  8.30204e+07      2.22306e+07                   8.34069e+06
# 2017-06-30   8.4124e+07      2.30428e+07                   8.75734e+06
# 2017-03-31  8.07339e+07      2.12974e+07                   7.23026e+06
# 2016-12-31  8.38414e+07      2.38869e+07                   7.87685e+06
# 2016-09-30  7.91102e+07       1.9991e+07                   7.28522e+06
# 2016-06-30  7.66567e+07      1.85615e+07                   5.72965e+06
# 2016-03-31   8.0248e+07      1.90745e+07                   6.00732e+06
# 2015-12-31  9.01762e+07      2.83145e+07                   1.36202e+07
# 2015-09-30  8.80432e+07      2.38354e+07                   9.68086e+06
# 2015-06-30  7.44362e+07      1.83603e+07                   6.89978e+06
# 2015-03-31     75101184       1.9241e+07                   6.97458e+06
# 2014-12-31  7.21432e+07      2.07284e+07                   9.72207e+06
# 2014-09-30  6.51259e+07      1.54466e+07                   5.74812e+06
# 2014-06-30   6.2989e+07      1.57733e+07                   6.27386e+06
# 2014-03-31   6.3297e+07      1.63523e+07                   7.29618e+06
# 2013-12-31   6.8674e+07        2.047e+07                   1.12858e+07
# 2013-09-30   5.9619e+07      1.24784e+07                   4.83517e+06
# 2013-06-30  5.87393e+07      1.20571e+07                   4.48217e+06
# 2013-03-31  1.34037e+06            77552                         74204
# 2012-12-31   1.3463e+06            71641                         48155
#
#            Aplicações Financeiras Contas a Receber     Estoques  \
# ABEV3
# 2020-12-31            1.70003e+06      4.30314e+06   7.6059e+06
# 2020-09-30            1.44292e+06      4.15692e+06  7.34184e+06
# 2020-06-30                  44823      4.20158e+06  7.77162e+06
# 2020-03-31                  44823       3.3943e+06  7.75266e+06
# 2019-12-31                  14558      4.49552e+06  5.97856e+06
# 2019-09-30                  14304      4.23626e+06  5.97881e+06
# 2019-06-30                  14038      4.10312e+06  6.19756e+06
# 2019-03-31                  13772      3.98036e+06  6.03274e+06
# 2018-12-31                  13391      4.87926e+06  5.40179e+06
# 2018-09-30                  13008      4.28563e+06  5.34909e+06
# 2018-06-30                  12618      4.41272e+06  4.93328e+06
# 2018-03-31                  12229      3.53711e+06  4.72512e+06
# 2017-12-31                  11883      4.94483e+06  4.31897e+06
# 2017-09-30                   7820      3.76777e+06  4.37339e+06
# 2017-06-30                   8770       3.5722e+06  4.66395e+06
# 2017-03-31                   9903      3.26737e+06  4.51032e+06
# 2016-12-31                 282771      4.36806e+06  4.34705e+06
# 2016-09-30                 274577      3.79334e+06  4.27581e+06
# 2016-06-30                 263893      3.44576e+06  4.40395e+06
# 2016-03-31                 209067      3.14611e+06  4.89606e+06
# 2015-12-31                 215106      4.16567e+06  4.33817e+06
# 2015-09-30                 718737      3.54709e+06  4.52142e+06
# 2015-06-30                 776569      2.85036e+06  4.07868e+06
# 2015-03-31            1.03376e+06       2.8977e+06  4.37789e+06
# 2014-12-31                 712958      3.02885e+06  3.41128e+06
# 2014-09-30                 526789      3.27564e+06  3.15897e+06
# 2014-06-30                 379938      3.53838e+06  3.12046e+06
# 2014-03-31                 410173      3.11009e+06   3.0623e+06
# 2013-12-31                 288604      3.61351e+06  2.79549e+06
# 2013-09-30                 612489      2.74785e+06  2.58654e+06
# 2013-06-30                 486133      2.78314e+06  2.72625e+06
# 2013-03-31                      0             3105            0
# 2012-12-31                      0            21490            0
#
#            Ativos Biológicos Tributos a Recuperar Despesas Antecipadas  \
# ABEV3
# 2020-12-31                 0          3.28714e+06               293552
# 2020-09-30                 0          3.47288e+06               298303
# 2020-06-30                 0          5.39034e+06               356411
# 2020-03-31                 0          5.26641e+06               447474
# 2019-12-31                 0          4.07413e+06               512532
# 2019-09-30                 0          2.54586e+06               293060
# 2019-06-30                 0          1.54256e+06               507216
# 2019-03-31                 0          1.98034e+06               591274
# 2018-12-31                 0          2.14871e+06               741222
# 2018-09-30                 0          2.21503e+06               439839
# 2018-06-30                 0          4.10303e+06               718994
# 2018-03-31                 0          3.67505e+06               751004
# 2017-12-31                 0          3.37054e+06               771499
# 2017-09-30                 0          4.43278e+06               604183
# 2017-06-30                 0          4.52914e+06               796164
# 2017-03-31                 0          4.96856e+06               719635
# 2016-12-31                 0          5.42331e+06               771257
# 2016-09-30                 0          3.18321e+06               688917
# 2016-06-30                 0          3.23265e+06               703987
# 2016-03-31                 0          3.17934e+06               748560
# 2015-12-31                 0          3.19497e+06          1.01714e+06
# 2015-09-30                 0          1.29041e+06               825520
# 2015-06-30                 0          1.43656e+06               630522
# 2015-03-31                 0           1.3943e+06               701362
# 2014-12-31                 0          1.58191e+06               781603
# 2014-09-30                 0          1.70601e+06               539432
# 2014-06-30                 0          1.51042e+06               553012
# 2014-03-31                 0          1.42052e+06               682212
# 2013-12-31                 0            1.397e+06               787333
# 2013-09-30                 0               850674               593453
# 2013-06-30                 0               739122               627320
# 2013-03-31                 0                  243                    0
# 2012-12-31                 0                 1996                    0
#
#            Outros Ativos Circulantes  ... Receitas Despesas  \
# ABEV3                                 ...
# 2020-12-31               1.06251e+06  ...      NaN      NaN
# 2020-09-30                    725479  ...      NaN      NaN
# 2020-06-30                1.0644e+06  ...      NaN      NaN
# 2020-03-31                    976225  ...      NaN      NaN
# 2019-12-31                    645172  ...      NaN      NaN
# 2019-09-30                    918815  ...      NaN      NaN
# 2019-06-30                    758141  ...      NaN      NaN
# 2019-03-31                    773121  ...      NaN      NaN
# 2018-12-31                    681731  ...      NaN      NaN
# 2018-09-30               1.66976e+06  ...      NaN      NaN
# 2018-06-30               1.60851e+06  ...      NaN      NaN
# 2018-03-31                    906562  ...      NaN      NaN
# 2017-12-31                    945819  ...      NaN      NaN
# 2017-09-30                    703954  ...      NaN      NaN
# 2017-06-30                    715286  ...      NaN      NaN
# 2017-03-31                    591317  ...      NaN      NaN
# 2016-12-31                    817553  ...      NaN      NaN
# 2016-09-30                    489904  ...      NaN      NaN
# 2016-06-30                    781624  ...      NaN      NaN
# 2016-03-31                    888026  ...      NaN      NaN
# 2015-12-31               1.76327e+06  ...      NaN      NaN
# 2015-09-30               3.25132e+06  ...      NaN      NaN
# 2015-06-30                   1687776  ...      NaN      NaN
# 2015-03-31               1.86143e+06  ...      NaN      NaN
# 2014-12-31               1.48975e+06  ...      NaN      NaN
# 2014-09-30                    491612  ...      NaN      NaN
# 2014-06-30                    397196  ...      NaN      NaN
# 2014-03-31                    370844  ...      NaN      NaN
# 2013-12-31                    302243  ...      NaN      NaN
# 2013-09-30                    252198  ...      NaN      NaN
# 2013-06-30                    212913  ...      NaN      NaN
# 2013-03-31                         0  ...      NaN      NaN
# 2012-12-31                         0  ...      NaN      NaN
#
#            Resultado Antes Tributação/Participações  \
# ABEV3
# 2020-12-31                              8.46431e+06
# 2020-09-30                                  2431040
# 2020-06-30                              1.10817e+06
# 2020-03-31                              1.49092e+06
# 2019-12-31                              3.75505e+06
# 2019-09-30                              2.82642e+06
# 2019-06-30                              2.98001e+06
# 2019-03-31                              3.38153e+06
# 2018-12-31                              4.59141e+06
# 2018-09-30                               2.7544e+06
# 2018-06-30                              2.60372e+06
# 2018-03-31                              3.21749e+06
# 2017-12-31                              5.02186e+06
# 2017-09-30                               2.9343e+06
# 2017-06-30                              2.34529e+06
# 2017-03-31                              2.62834e+06
# 2016-12-31                              5.36407e+06
# 2016-09-30                              2.40482e+06
# 2016-06-30                                  2399104
# 2016-03-31                              3.23038e+06
# 2015-12-31                              5.93734e+06
# 2015-09-30                              3.90164e+06
# 2015-06-30                              2.76008e+06
# 2015-03-31                              3.91433e+06
# 2014-12-31                              5.47601e+06
# 2014-09-30                              3.27233e+06
# 2014-06-30                              2.47158e+06
# 2014-03-31                              3.14866e+06
# 2013-12-31                               8.2132e+06
# 2013-09-30                              3.17147e+06
# 2013-06-30                              2.41702e+06
# 2013-03-31                                     9996
# 2012-12-31                                      NaN
#
#            Provisão para IR e Contribuição Social  IR Diferido  \
# ABEV3
# 2020-12-31                                  93644 -1.66758e+06
# 2020-09-30                                -415548       343476
# 2020-06-30                                -431945       595088
# 2020-03-31                                -295033        15365
# 2019-12-31                            1.31792e+06      -853995
# 2019-09-30                                -649270       427238
# 2019-06-30                                -807524       443414
# 2019-03-31                                -979185       346724
# 2018-12-31                                33055.1 -1.16093e+06
# 2018-09-30                                -475185       612890
# 2018-06-30                                -663297       483739
# 2018-03-31                                -728053       108190
# 2017-12-31                                -358014  -1.3645e+06
# 2017-09-30                           -3.71527e+06       917454
# 2017-06-30                                -577296       356837
# 2017-03-31                                -681759       343246
# 2016-12-31                            1.28343e+06 -1.81376e+06
# 2016-09-30                                -524936      1303264
# 2016-06-30                                -533547       306964
# 2016-03-31                                -638854       302471
# 2015-12-31                                 602026 -2.28085e+06
# 2015-09-30                                -525990      -308710
# 2015-06-30                                -380469       211232
# 2015-03-31                                -923455       -28029
# 2014-12-31                                  42471      -859414
# 2014-09-30                                -857676       475888
# 2014-06-30                                -286887        30916
# 2014-03-31                                -955092       403236
# 2013-12-31                                -910939      -197098
# 2013-09-30                                -370166      -462300
# 2013-06-30                                -630949       114066
# 2013-03-31                                   -158          -70
# 2012-12-31                                    NaN          NaN
#
#            Participações/Contribuições Estatutárias  \
# ABEV3
# 2020-12-31                                      NaN
# 2020-09-30                                      NaN
# 2020-06-30                                      NaN
# 2020-03-31                                      NaN
# 2019-12-31                                      NaN
# 2019-09-30                                      NaN
# 2019-06-30                                      NaN
# 2019-03-31                                      NaN
# 2018-12-31                                      NaN
# 2018-09-30                                      NaN
# 2018-06-30                                      NaN
# 2018-03-31                                      NaN
# 2017-12-31                                      NaN
# 2017-09-30                                      NaN
# 2017-06-30                                      NaN
# 2017-03-31                                      NaN
# 2016-12-31                                      NaN
# 2016-09-30                                      NaN
# 2016-06-30                                      NaN
# 2016-03-31                                      NaN
# 2015-12-31                                      NaN
# 2015-09-30                                      NaN
# 2015-06-30                                      NaN
# 2015-03-31                                      NaN
# 2014-12-31                                      NaN
# 2014-09-30                                      NaN
# 2014-06-30                                      NaN
# 2014-03-31                                      NaN
# 2013-12-31                                      NaN
# 2013-09-30                                      NaN
# 2013-06-30                                      NaN
# 2013-03-31                                      NaN
# 2012-12-31                                      NaN
#
#            Reversão dos Juros sobre Capital Próprio  \
# ABEV3
# 2020-12-31                                      NaN
# 2020-09-30                                      NaN
# 2020-06-30                                      NaN
# 2020-03-31                                      NaN
# 2019-12-31                                      NaN
# 2019-09-30                                      NaN
# 2019-06-30                                      NaN
# 2019-03-31                                      NaN
# 2018-12-31                                      NaN
# 2018-09-30                                      NaN
# 2018-06-30                                      NaN
# 2018-03-31                                      NaN
# 2017-12-31                                      NaN
# 2017-09-30                                      NaN
# 2017-06-30                                      NaN
# 2017-03-31                                      NaN
# 2016-12-31                                      NaN
# 2016-09-30                                      NaN
# 2016-06-30                                      NaN
# 2016-03-31                                      NaN
# 2015-12-31                                      NaN
# 2015-09-30                                      NaN
# 2015-06-30                                      NaN
# 2015-03-31                                      NaN
# 2014-12-31                                      NaN
# 2014-09-30                                      NaN
# 2014-06-30                                      NaN
# 2014-03-31                                      NaN
# 2013-12-31                                      NaN
# 2013-09-30                                      NaN
# 2013-06-30                                      NaN
# 2013-03-31                                      NaN
# 2012-12-31                                      NaN
#
#            Part. de Acionistas Não Controladores Lucro/Prejuízo do Período  \
# ABEV3
# 2020-12-31                               -104363               6.78601e+06
# 2020-09-30                                -84167                2.2748e+06
# 2020-06-30                                -44517                1.2268e+06
# 2020-03-31                               -119468               1.09178e+06
# 2019-12-31                               -119273                4.0997e+06
# 2019-09-30                               -106708               2.49768e+06
# 2019-06-30                                -95168               2.52073e+06
# 2019-03-31                                -87218               2.66185e+06
# 2018-12-31                               -103126                3.3604e+06
# 2018-09-30                                -60947               2.83116e+06
# 2018-06-30                               -107009                   2317152
# 2018-03-31                                -81667               2.51596e+06
# 2017-12-31                               -179888               3.11946e+06
# 2017-09-30                               -136267                       223
# 2017-06-30                               -111685               2.01315e+06
# 2017-03-31                                -90696               2.19913e+06
# 2016-12-31                               -161375               4.67236e+06
# 2016-09-30                               -121917               3.06123e+06
# 2016-06-30                               -126367               2.04615e+06
# 2016-03-31                               -127128               2.76686e+06
# 2015-12-31                               -104796               4.15372e+06
# 2015-09-30                               -116209               2.95073e+06
# 2015-06-30                                -82185               2.50866e+06
# 2015-03-31                               -152180               2.81066e+06
# 2014-12-31                               -120675               4.53839e+06
# 2014-09-30                                -76946                2.8136e+06
# 2014-06-30                                -48724               2.16688e+06
# 2014-03-31                                -50162               2.54664e+06
# 2013-12-31                              -85133.1               6.09375e+06
# 2013-09-30                                -49296               2.28971e+06
# 2013-06-30                               -758399               1.14174e+06
# 2013-03-31                                   NaN                      9768
# 2012-12-31                                   NaN                       NaN
#
#             Adj Close
# ABEV3
# 2020-12-31  15.575767
# 2020-09-30  12.159024
# 2020-06-30  13.710416
# 2020-03-31  11.557861
# 2019-12-31  18.102791
# 2019-09-30  18.187490
# 2019-06-30  16.902554
# 2019-03-31  15.901062
# 2018-12-31  14.531096
# 2018-09-30  16.978544
# 2018-06-30  16.645267
# 2018-03-31  22.092726
# 2017-12-31  19.469629
# 2017-09-30  18.964655
# 2017-06-30  16.503935
# 2017-03-31  16.296621
# 2016-12-31  14.593514
# 2016-09-30  17.251490
# 2016-06-30  16.470163
# 2016-03-31  16.254025
# 2015-12-31  15.325160
# 2015-09-30  16.534142
# 2015-06-30  16.044369
# 2015-03-31  15.529536
# 2014-12-31  12.729816
# 2014-09-30  12.357684
# 2014-06-30  12.022855
# 2014-03-31  12.884299
# 2013-12-31  13.046216
# 2013-09-30  12.756972
# 2013-06-30  12.389745
# 2013-03-31  12.246234
# 2012-12-31  12.418349
#
# [33 rows x 80 columns]

# %% [markdown]
# ### Tratar colunas
#
# 1. Vamos pegar apenas empresas que possuem as mesmas colunas
# 2. Ajeitar colunas com nome repetido
# 3. Analisar valores vazios nas colunas

# %% [markdown]
# #### 1. Remover da análise tabelas que tem colunas diferentes.

# %%
colunas = list(fundamentos["ABEV3"].columns)

for empresa in empresas:
    if set(colunas) != set(fundamentos[empresa].columns):
        fundamentos.pop(empresa)
print(len(fundamentos))
# Out:
# 61

# %% [markdown]
# ####  2. Ajeitando colunas com o mesmo nome

# %%
print(colunas)
# Out:
# ['Ativo Total', 'Ativo Circulante', 'Caixa e Equivalentes de Caixa', 'Aplicações Financeiras', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos a Recuperar', 'Despesas Antecipadas', 'Outros Ativos Circulantes', 'Ativo Realizável a Longo Prazo', 'Aplicações Financeiras Avaliadas a Valor Justo', 'Aplicações Financeiras Avaliadas ao Custo Amortizado', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos Diferidos', 'Despesas Antecipadas', 'Créditos com Partes Relacionadas', 'Outros Ativos Não Circulantes', 'Investimentos', 'Imobilizado', 'Intangível', 'Diferido', 'Passivo Total', 'Passivo Circulante', 'Obrigações Sociais e Trabalhistas', 'Fornecedores', 'Obrigações Fiscais', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Dividendos e JCP a Pagar', 'Outros', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Passivo Não Circulante', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Outros', 'Tributos Diferidos', 'Adiantamento para Futuro Aumento Capital', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Lucros e Receitas a Apropriar', 'Participação dos Acionistas Não Controladores', 'Patrimônio Líquido', 'Capital Social Realizado', 'Reservas de Capital', 'Reservas de Reavaliação', 'Reservas de Lucros', 'Lucros/Prejuízos Acumulados', 'Ajustes de Avaliação Patrimonial', 'Ajustes Acumulados de Conversão', 'Outros Resultados Abrangentes', 'Adiantamento para Futuro Aumento Capital', 'Receita Bruta de Vendas e/ou Serviços', 'Deduções da Receita Bruta', 'Receita Líquida de Vendas e/ou Serviços', 'Custo de Bens e/ou Serviços Vendidos', 'Resultado Bruto', 'Despesas Com Vendas', 'Despesas Gerais e Administrativas', 'Perdas pela Não Recuperabilidade de Ativos\xa0', 'Outras Receitas Operacionais', 'Outras Despesas Operacionais', 'Resultado da Equivalência Patrimonial', 'Financeiras', 'Receitas Financeiras', 'Despesas Financeiras', 'Resultado Não Operacional', 'Receitas', 'Despesas', 'Resultado Antes Tributação/Participações', 'Provisão para IR e Contribuição Social', 'IR Diferido', 'Participações/Contribuições Estatutárias', 'Reversão dos Juros sobre Capital Próprio', 'Part. de Acionistas Não Controladores', 'Lucro/Prejuízo do Período', 'Adj Close']

# %%
texto_colunas = ";".join(colunas)
print(texto_colunas)
# Out:
# Ativo Total;Ativo Circulante;Caixa e Equivalentes de Caixa;Aplicações Financeiras;Contas a Receber;Estoques;Ativos Biológicos;Tributos a Recuperar;Despesas Antecipadas;Outros Ativos Circulantes;Ativo Realizável a Longo Prazo;Aplicações Financeiras Avaliadas a Valor Justo;Aplicações Financeiras Avaliadas ao Custo Amortizado;Contas a Receber;Estoques;Ativos Biológicos;Tributos Diferidos;Despesas Antecipadas;Créditos com Partes Relacionadas;Outros Ativos Não Circulantes;Investimentos;Imobilizado;Intangível;Diferido;Passivo Total;Passivo Circulante;Obrigações Sociais e Trabalhistas;Fornecedores;Obrigações Fiscais;Empréstimos e Financiamentos;Passivos com Partes Relacionadas;Dividendos e JCP a Pagar;Outros;Provisões;Passivos sobre Ativos Não-Correntes a Venda e Descontinuados;Passivo Não Circulante;Empréstimos e Financiamentos;Passivos com Partes Relacionadas;Outros;Tributos Diferidos;Adiantamento para Futuro Aumento Capital;Provisões;Passivos sobre Ativos Não-Correntes a Venda e Descontinuados;Lucros e Receitas a Apropriar;Participação dos Acionistas Não Controladores;Patrimônio Líquido;Capital Social Realizado;Reservas de Capital;Reservas de Reavaliação;Reservas de Lucros;Lucros/Prejuízos Acumulados;Ajustes de Avaliação Patrimonial;Ajustes Acumulados de Conversão;Outros Resultados Abrangentes;Adiantamento para Futuro Aumento Capital;Receita Bruta de Vendas e/ou Serviços;Deduções da Receita Bruta;Receita Líquida de Vendas e/ou Serviços;Custo de Bens e/ou Serviços Vendidos;Resultado Bruto;Despesas Com Vendas;Despesas Gerais e Administrativas;Perdas pela Não Recuperabilidade de Ativos ;Outras Receitas Operacionais;Outras Despesas Operacionais;Resultado da Equivalência Patrimonial;Financeiras;Receitas Financeiras;Despesas Financeiras;Resultado Não Operacional;Receitas;Despesas;Resultado Antes Tributação/Participações;Provisão para IR e Contribuição Social;IR Diferido;Participações/Contribuições Estatutárias;Reversão dos Juros sobre Capital Próprio;Part. de Acionistas Não Controladores;Lucro/Prejuízo do Período;Adj Close

# %%
texto_colunas = ";".join(colunas)

colunas_modificadas = []
for coluna in colunas:
    if colunas.count(coluna) == 2 and coluna not in colunas_modificadas:
        texto_colunas = texto_colunas.replace(";" + coluna + ";",";" + coluna + "_1;", 1)
        colunas_modificadas.append(coluna)
colunas = texto_colunas.split(';')
print(colunas)
# Out:
# ['Ativo Total', 'Ativo Circulante', 'Caixa e Equivalentes de Caixa', 'Aplicações Financeiras', 'Contas a Receber_1', 'Estoques_1', 'Ativos Biológicos_1', 'Tributos a Recuperar', 'Despesas Antecipadas_1', 'Outros Ativos Circulantes', 'Ativo Realizável a Longo Prazo', 'Aplicações Financeiras Avaliadas a Valor Justo', 'Aplicações Financeiras Avaliadas ao Custo Amortizado', 'Contas a Receber', 'Estoques', 'Ativos Biológicos', 'Tributos Diferidos_1', 'Despesas Antecipadas', 'Créditos com Partes Relacionadas', 'Outros Ativos Não Circulantes', 'Investimentos', 'Imobilizado', 'Intangível', 'Diferido', 'Passivo Total', 'Passivo Circulante', 'Obrigações Sociais e Trabalhistas', 'Fornecedores', 'Obrigações Fiscais', 'Empréstimos e Financiamentos_1', 'Passivos com Partes Relacionadas_1', 'Dividendos e JCP a Pagar', 'Outros_1', 'Provisões_1', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados_1', 'Passivo Não Circulante', 'Empréstimos e Financiamentos', 'Passivos com Partes Relacionadas', 'Outros', 'Tributos Diferidos', 'Adiantamento para Futuro Aumento Capital_1', 'Provisões', 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados', 'Lucros e Receitas a Apropriar', 'Participação dos Acionistas Não Controladores', 'Patrimônio Líquido', 'Capital Social Realizado', 'Reservas de Capital', 'Reservas de Reavaliação', 'Reservas de Lucros', 'Lucros/Prejuízos Acumulados', 'Ajustes de Avaliação Patrimonial', 'Ajustes Acumulados de Conversão', 'Outros Resultados Abrangentes', 'Adiantamento para Futuro Aumento Capital', 'Receita Bruta de Vendas e/ou Serviços', 'Deduções da Receita Bruta', 'Receita Líquida de Vendas e/ou Serviços', 'Custo de Bens e/ou Serviços Vendidos', 'Resultado Bruto', 'Despesas Com Vendas', 'Despesas Gerais e Administrativas', 'Perdas pela Não Recuperabilidade de Ativos\xa0', 'Outras Receitas Operacionais', 'Outras Despesas Operacionais', 'Resultado da Equivalência Patrimonial', 'Financeiras', 'Receitas Financeiras', 'Despesas Financeiras', 'Resultado Não Operacional', 'Receitas', 'Despesas', 'Resultado Antes Tributação/Participações', 'Provisão para IR e Contribuição Social', 'IR Diferido', 'Participações/Contribuições Estatutárias', 'Reversão dos Juros sobre Capital Próprio', 'Part. de Acionistas Não Controladores', 'Lucro/Prejuízo do Período', 'Adj Close']

# %%
# implementar as colunas nas tabelas

for empresa in fundamentos:
    fundamentos[empresa].columns = colunas

# %% [markdown]
# #### 3. Analisar valores vazios nas colunas

# %%
# valores_vazios = {
#     "Ativo Total": 0,
#     "Passivo Total": 0,
# }
valores_vazios = dict.fromkeys(colunas, 0)
total_linhas = 0
for empresa in fundamentos:
    tabela = fundamentos[empresa]
    total_linhas += tabela.shape[0]
    for coluna in colunas:
        qtde_vazios = pd.isnull(tabela[coluna]).sum()
        valores_vazios[coluna] += qtde_vazios
print(valores_vazios)
print(total_linhas)
# Out:
# {'Ativo Total': 0, 'Ativo Circulante': 0, 'Caixa e Equivalentes de Caixa': 0, 'Aplicações Financeiras': 0, 'Contas a Receber_1': 0, 'Estoques_1': 0, 'Ativos Biológicos_1': 0, 'Tributos a Recuperar': 0, 'Despesas Antecipadas_1': 0, 'Outros Ativos Circulantes': 0, 'Ativo Realizável a Longo Prazo': 0, 'Aplicações Financeiras Avaliadas a Valor Justo': 0, 'Aplicações Financeiras Avaliadas ao Custo Amortizado': 0, 'Contas a Receber': 0, 'Estoques': 0, 'Ativos Biológicos': 0, 'Tributos Diferidos_1': 0, 'Despesas Antecipadas': 0, 'Créditos com Partes Relacionadas': 0, 'Outros Ativos Não Circulantes': 0, 'Investimentos': 0, 'Imobilizado': 0, 'Intangível': 0, 'Diferido': 0, 'Passivo Total': 0, 'Passivo Circulante': 0, 'Obrigações Sociais e Trabalhistas': 0, 'Fornecedores': 0, 'Obrigações Fiscais': 0, 'Empréstimos e Financiamentos_1': 0, 'Passivos com Partes Relacionadas_1': 0, 'Dividendos e JCP a Pagar': 0, 'Outros_1': 0, 'Provisões_1': 0, 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados_1': 0, 'Passivo Não Circulante': 0, 'Empréstimos e Financiamentos': 0, 'Passivos com Partes Relacionadas': 0, 'Outros': 0, 'Tributos Diferidos': 0, 'Adiantamento para Futuro Aumento Capital_1': 0, 'Provisões': 0, 'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados': 0, 'Lucros e Receitas a Apropriar': 0, 'Participação dos Acionistas Não Controladores': 0, 'Patrimônio Líquido': 0, 'Capital Social Realizado': 0, 'Reservas de Capital': 0, 'Reservas de Reavaliação': 0, 'Reservas de Lucros': 0, 'Lucros/Prejuízos Acumulados': 0, 'Ajustes de Avaliação Patrimonial': 0, 'Ajustes Acumulados de Conversão': 0, 'Outros Resultados Abrangentes': 0, 'Adiantamento para Futuro Aumento Capital': 0, 'Receita Bruta de Vendas e/ou Serviços': 2004, 'Deduções da Receita Bruta': 2004, 'Receita Líquida de Vendas e/ou Serviços': 2, 'Custo de Bens e/ou Serviços Vendidos': 2, 'Resultado Bruto': 2, 'Despesas Com Vendas': 2, 'Despesas Gerais e Administrativas': 2, 'Perdas pela Não Recuperabilidade de Ativos\xa0': 2, 'Outras Receitas Operacionais': 2, 'Outras Despesas Operacionais': 2, 'Resultado da Equivalência Patrimonial': 2, 'Financeiras': 2, 'Receitas Financeiras': 2, 'Despesas Financeiras': 2, 'Resultado Não Operacional': 2004, 'Receitas': 2004, 'Despesas': 2004, 'Resultado Antes Tributação/Participações': 2, 'Provisão para IR e Contribuição Social': 2, 'IR Diferido': 2, 'Participações/Contribuições Estatutárias': 2004, 'Reversão dos Juros sobre Capital Próprio': 2004, 'Part. de Acionistas Não Controladores': 58, 'Lucro/Prejuízo do Período': 2, 'Adj Close': 0}
# 2004

# %%
remover_colunas = []
for coluna in valores_vazios:
    if valores_vazios[coluna] > 50:
        remover_colunas.append(coluna)

for empresa in fundamentos:
    fundamentos[empresa] = fundamentos[empresa].drop(remover_colunas, axis=1)
    fundamentos[empresa] = fundamentos[empresa].ffill()

# %%
fundamentos["ABEV3"].shape
# Out:
# (33, 72)

# %% [markdown]
# ### Criando os rótulos: Comprar, Não Comprar ou Vender?
#
# Não queremos saber quando vender, mas inclui essa categoria para conseguir identificar quando que o nosso modelo vai sugerir uma compra quando na verdade o melhor momento era vender. Isso significa que o modelo errou "mais" do que quando sugeriu comprar e simplesmente o certo era não comprar
#
# Regra:
# 1. Subiu mais do que o Ibovespa (ou caiu menos) -> Comprar (Valor = 2)
# 2. Subiu menos do que o Ibovespa até Ibovespa - 2% (ou caiu mais do que Ibovespa até Ibovespa -2%) -> Não Comprar (Valor = 1)
# 3. Subiu menos do que o Ibovespa - 2% (ou caiu mais do que Ibovespa -2%) -> Vender (Valor = 0)

# %%
df_ibov=pd.read_csv("cotações de dez 2012 abril 2021^BVSP.csv")
display(df_ibov)
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     2012-12-20   60992.0   61276.0   60622.0   61276.0    61276.0
# 1     2012-12-21   61271.0   61271.0   60221.0   61007.0    61007.0
# 2     2012-12-26   61003.0   61322.0   60861.0   60960.0    60960.0
# 3     2012-12-27   60964.0   61191.0   60233.0   60416.0    60416.0
# 4     2012-12-28   60416.0   61066.0   60416.0   60952.0    60952.0
# ...          ...       ...       ...       ...       ...        ...
# 2060  2021-04-14  119298.0  120871.0  119298.0  120295.0   120295.0
# 2061  2021-04-15  120290.0  121409.0  120084.0  120701.0   120701.0
# 2062  2021-04-16  120701.0  121333.0  120199.0  121114.0   121114.0
# 2063  2021-04-19  121116.0  121974.0  120682.0  120934.0   120934.0
# 2064  2021-04-20  120925.0  121354.0  119841.0  120062.0   120062.0
#
#           Volume
# 0      3083400.0
# 1      3157400.0
# 2      2598000.0
# 3      2852600.0
# 4      2626000.0
# ...          ...
# 2060  10076600.0
# 2061   7948100.0
# 2062   7945600.0
# 2063  10028100.0
# 2064   7811500.0
#
# [2065 rows x 7 columns]

# %%
datas = fundamentos["ABEV3"].index
print(datas)
# Out:
# DatetimeIndex(['2020-12-31', '2020-09-30', '2020-06-30', '2020-03-31',
#                '2019-12-31', '2019-09-30', '2019-06-30', '2019-03-31',
#                '2018-12-31', '2018-09-30', '2018-06-30', '2018-03-31',
#                '2017-12-31', '2017-09-30', '2017-06-30', '2017-03-31',
#                '2016-12-31', '2016-09-30', '2016-06-30', '2016-03-31',
#                '2015-12-31', '2015-09-30', '2015-06-30', '2015-03-31',
#                '2014-12-31', '2014-09-30', '2014-06-30', '2014-03-31',
#                '2013-12-31', '2013-09-30', '2013-06-30', '2013-03-31',
#                '2012-12-31'],
#               dtype='datetime64[ns]', name='ABEV3', freq='-1Q-DEC')

# %%
import numpy as np
datas = fundamentos["ABEV3"].index
for data in datas:
    if data not in df_ibov.index:
        df_ibov.loc[data] = np.nan
df_ibov = df_ibov.sort_index()
df_ibov = df_ibov.ffill()
display(df_ibov)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-322df7fc563a> in <module>
#       4     if data not in df_ibov.index:
#       5         df_ibov.loc[data] = np.nan
# ----> 6 df_ibov = df_ibov.sort_index()
#       7 df_ibov = df_ibov.ffill()
#       8 display(df_ibov)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index)
#    4998                     return self.copy()
#    4999
# -> 5000             indexer = nargsort(
#    5001                 labels, kind=kind, ascending=ascending, na_position=na_position
#    5002             )
#
# ~\anaconda3\lib\site-packages\pandas\core\sorting.py in nargsort(items, kind, ascending, na_position)
#     272         non_nans = non_nans[::-1]
#     273         non_nan_idx = non_nan_idx[::-1]
# --> 274     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     275     if not ascending:
#     276         indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'Timestamp' and 'int'

# %%
df_ibov = df_ibov.rename(columns={"Adj Close": "IBOV"})
display(df_ibov)

# %%
for empresa in fundamentos:
    fundamentos[empresa] = fundamentos[empresa].merge(df_ibov[["IBOV"]], left_index=True, right_index=True)
display(fundamentos["ABEV3"])

# %%
# tornar os nossos indicadores em percentuais
# fundamento%tri = fundamento tr / fundamento tri anterior
# cotacao%tri = cotacao tri seguinte / cotacao tri
for empresa in fundamentos:
    fundamento = fundamentos[empresa]
    fundamento = fundamento.sort_index()
    for coluna in fundamento:
        if "Adj Close" in coluna or "IBOV" in coluna:
            pass
        else:
            # pegar a cotação anterior
            condicoes = [
                (fundamento[coluna].shift(1) > 0) & (fundamento[coluna] < 0),
                (fundamento[coluna].shift(1) < 0) & (fundamento[coluna] > 0),
                (fundamento[coluna].shift(1) < 0) & (fundamento[coluna] < 0),
                (fundamento[coluna].shift(1) == 0) & (fundamento[coluna] > 0),
                (fundamento[coluna].shift(1) == 0) & (fundamento[coluna] < 0),
                (fundamento[coluna].shift(1) < 0) & (fundamento[coluna] == 0),
            ]
            valores = [
                -1,
                1,
                (abs(fundamento[coluna].shift(1)) - abs(fundamento[coluna])) / abs(fundamento[coluna].shift(1)),
                1,
                -1,
                1,
            ]
            fundamento[coluna] = np.select(condicoes, valores, default=fundamento[coluna] / fundamento[coluna].shift(1) - 1)
    # pegar cotação seguinte
    fundamento["Adj Close"] = fundamento["Adj Close"].shift(-1) / fundamento["Adj Close"] - 1
    fundamento["IBOV"] = fundamento["IBOV"].shift(-1) / fundamento["IBOV"] - 1
    fundamento["Resultado"] = fundamento["Adj Close"] - fundamento["IBOV"]
    condicoes = [
        (fundamento["Resultado"] > 0),
        (fundamento["Resultado"] < 0) & (fundamento["Resultado"] >= -0.02),
        (fundamento["Resultado"] < -0.02)
    ]
    valores = [2, 1, 0]
    fundamento["Decisao"] = np.select(condicoes, valores)
    
    fundamentos[empresa] = fundamento
display(fundamentos["ABEV3"])

# %%
# remover valores vazios
colunas = list(fundamentos["ABEV3"].columns)
valores_vazios = dict.fromkeys(colunas, 0)
total_linhas = 0
for empresa in fundamentos:
    tabela = fundamentos[empresa]
    total_linhas += tabela.shape[0]
    for coluna in colunas:
        qtde_vazios = pd.isnull(tabela[coluna]).sum()
        valores_vazios[coluna] += qtde_vazios
print(valores_vazios)
print(total_linhas)

# %%
remover_colunas = []
for coluna in valores_vazios:
    if valores_vazios[coluna] > (total_linhas / 3):
        remover_colunas.append(coluna)

for empresa in fundamentos:
    fundamentos[empresa] = fundamentos[empresa].drop(remover_colunas, axis=1)
    fundamentos[empresa] = fundamentos[empresa].fillna(0)

# %%
for empresa in fundamentos:
    fundamentos[empresa] = fundamentos[empresa].drop(["Adj Close", "IBOV", "Resultado"], axis=1)
print(fundamentos["ABEV3"].shape)

# %% [markdown]
# ### Hora de tornar tudo 1 dataframe só

# %%
copia_fundamentos = fundamentos.copy()

# %%
base_dados = pd.DataFrame()
for empresa in copia_fundamentos:
    copia_fundamentos[empresa] = copia_fundamentos[empresa][1:-1]
    copia_fundamentos[empresa] = copia_fundamentos[empresa].reset_index(drop=True)
    base_dados = base_dados.append(copia_fundamentos[empresa])
display(base_dados)

# %% [markdown]
# ### Análise Exploratória

# %% [markdown]
# #### 1. Quantidade de Respostas em cada Tipo de Decisão

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

display(base_dados['Decisao'].value_counts(normalize=True).map("{:.1%}".format))
fig = px.histogram(base_dados, x="Decisao", color="Decisao")
fig.show()

# %%
# vou tirar a categoria 1 e transformar em 0
base_dados.loc[base_dados["Decisao"]==1, "Decisao"] = 0
display(base_dados['Decisao'].value_counts(normalize=True).map("{:.1%}".format))
fig = px.histogram(base_dados, x="Decisao", color="Decisao")
fig.show()

# %% [markdown]
# #### 2. Correlação

# %%
correlacoes = base_dados.corr()

fig, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(correlacoes, cmap="Wistia", ax=ax)
plt.show()
display(correlacoes)

# %% [markdown]
# #### Vamos remover Todas as Colunas "já explicadas" pelo Ativo Total

# %%
correlacoes_encontradas = []
for coluna in correlacoes:
    for linha in correlacoes.index:
        if linha != coluna:
            valor = abs(correlacoes.loc[linha, coluna])
            if valor > 0.8 and (coluna, linha, valor) not in correlacoes_encontradas:
                correlacoes_encontradas.append((linha, coluna, valor))
                print(f"Correlação Encontrada: {linha} e {coluna}. Valor: {valor}")

# %%
remover = ['Ativo Circulante', 'Contas a Receber_1', 'Tributos a Recuperar', 'Passivo Total', 'Passivo Circulante', 'Patrimônio Líquido', 'Capital Social Realizado', 'Receita Líquida de Vendas e/ou Serviços', 'Resultado Bruto', 'Despesas Gerais e Administrativas']
base_dados = base_dados.drop(remover, axis=1)
print(base_dados.shape)

# %% [markdown]
# ### Vamos partir para Feature Selection
#
# Será que todas essas features são importantes mesmo para o nosso modelo? Muitas features nem sempre é bom, se pudermos reduzir sem perder eficiência do nosso modelo, melhor
#
# Aqui temos 2 alternativas:
#
# 1. Seguir com todas as features e depois tentar melhorar o nosso modelo
# 2. Usar algum critério para selecionar as melhores features para prever e criar o modelo a partir apenas dessa seleção menor de features
#
# Vou seguir com a opção 2, porque é mais rápida e, caso dê certo, facilita a nossa vida. Se der errado, a gente volta aqui e refaz o processo

# %%
# vamos treinar uma arvore de decisao e pegar as caracteristicas mais importantes dela
from sklearn.ensemble import ExtraTreesClassifier

modelo = ExtraTreesClassifier(random_state=1)
x = base_dados.drop("Decisao", axis=1)
y = base_dados["Decisao"]
modelo.fit(x, y)

caracteristicas_importantes = pd.DataFrame(modelo.feature_importances_, x.columns).sort_values(by=0, ascending=False)
display(caracteristicas_importantes)
top10 = list(caracteristicas_importantes.index)[:10]
print(top10)

# %% [markdown]
# ### Aplicação do StandardScaler para melhorar nossos modelos de MachineLearning

# %%
from sklearn.preprocessing import StandardScaler

def ajustar_scaler(tabela_original):
    scaler = StandardScaler()
    tabela_auxiliar = tabela_original.drop("Decisao", axis=1)
    
    tabela_auxiliar = pd.DataFrame(scaler.fit_transform(tabela_auxiliar), tabela_auxiliar.index, tabela_auxiliar.columns)
    tabela_auxiliar["Decisao"] = tabela_original["Decisao"]
    return tabela_auxiliar

nova_base_dados = ajustar_scaler(base_dados)
top10.append("Decisao") 

nova_base_dados = nova_base_dados[top10].reset_index(drop=True)
display(nova_base_dados)

# %% [markdown]
# ### Separação dos dados em treino e teste

# %%
from sklearn.model_selection import train_test_split

x = nova_base_dados.drop("Decisao", axis=1)
y = nova_base_dados["Decisao"]

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, random_state=1)

# %% [markdown]
# ### Criação de um Dummy Classifier (Uma baseline para ver se os nossos modelos são melhores do que puro chute)

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import classification_report, confusion_matrix

dummy = DummyClassifier(strategy="stratified", random_state=2)
dummy.fit(x_treino, y_treino)
previsao_dummy = dummy.predict(x_teste)

# %% [markdown]
# ### Métricas de Avaliação
#
# - Precisão vai ser nossa métrica principal
# - Recall pode ser útil, mas precisão no caso de ações é mt mais importante.
#
# Explicação: Foto dos Gatos e Cachorros na Wikipedia: https://en.wikipedia.org/wiki/Precision_and_recall

# %%
def avaliar(y_teste, previsoes, nome_modelo):
    print(nome_modelo)
    report = classification_report(y_teste, previsoes)
    print(report)
    cf_matrix = pd.DataFrame(confusion_matrix(y_teste, previsoes), index=["Vender", "Comprar"], columns=["Vender", "Comprar"])
    sns.heatmap(cf_matrix, annot=True, cmap="Blues", fmt=',')
    plt.show()
    print("#" * 50)
    
    
avaliar(y_teste, previsao_dummy, "Dummy")

# %% [markdown]
# ### Modelos que vamos testar
# - AdaBoost
# - Decision Tree
# - Random Forest
# - ExtraTree
# - Gradient Boost
# - K Nearest Neighbors (KNN)
# - Logistic Regression
# - Naive Bayes
# - Support Vector Machine (SVM)
# - Rede Neural

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

modelos = {
    "AdaBoost": AdaBoostClassifier(random_state=1),
    "DecisionTree": DecisionTreeClassifier(random_state=1),
    "RandomForest": RandomForestClassifier(random_state=1),
    "ExtraTree": ExtraTreesClassifier(random_state=1),
    "GradientBoost": GradientBoostingClassifier(random_state=1),
    "KNN": KNeighborsClassifier(),
    "LogisticRegression": LogisticRegression(random_state=1),
    "NaiveBayes": GaussianNB(),
    "SVM": SVC(random_state=1),
    "RedeNeural": MLPClassifier(random_state=1, max_iter=400),
}

# %%
for nome_modelo in modelos:
    modelo = modelos[nome_modelo]
    modelo.fit(x_treino, y_treino)
    previsoes = modelo.predict(x_teste)
    avaliar(y_teste, previsoes, nome_modelo)
    modelos[nome_modelo] = modelo

# %% [markdown]
# ### Agora vamos ao tunning do modelo
#
# - é bom sempre incluir no tuning os parâmetros "padrões" do modelo, se não poder ser que vc só encontre resultados piores

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, precision_score

modelo_final = modelos["RandomForest"]

n_estimators = range(10, 251, 30)
max_features = list(range(2, 11, 2))
max_features.append('auto')
min_samples_split = range(2, 11, 2)

precision2_score = make_scorer(precision_score, labels=[2], average='macro')

grid = GridSearchCV(
        estimator=RandomForestClassifier(),
        param_grid={
            'n_estimators': n_estimators,
            'max_features': max_features,
            'min_samples_split': min_samples_split,
            'random_state': [1],
        },
        scoring=precision2_score,
)

resultado_grid = grid.fit(x_treino, y_treino)
print("Ajuste feito")

# %%
modelo_tunado = resultado_grid.best_estimator_
previsoes = modelo_tunado.predict(x_teste)
avaliar(y_teste, previsoes, "RandomForest Tunado")

# %% [markdown]
# ### Vamos seguir então com o Modelo Random Forest tunado para ser o nosso modelo
#
# - Agora ao que interessa...será que vamos conseguir escolher boas ações e ter uma carteira rentável?
# - Para isso, temos que pegar o último Trimestre (que não usamos para treinar o modelo nem testar) e ver como ele teria saído até o momento.

# %% [markdown]
# ### Repetindo os passos com a base fundamentos só que pegando apenas o último tri de cada empresa

# %%
# ult_tri_fundamentos é uma copia de fundamentos.
# foi necessario durante a construção dos dataframes, juntarmos todos em um só e copiamos o df de fundamentos como: copia_fundamentos = fundamentos.copy() como foi mostrado acima.
# Portanto vamos seguir o mesmo processo que fizemos com a copia.
# Criamos uma base de dados vazia e usamos essa copia_fundamentos para preencher essa base de dados, veja:
# base_dados = pd.DataFrame()
# for empresa in copia_fundamentos:
   # copia_fundamentos[empresa] = copia_fundamentos[empresa][1:-1]
   # copia_fundamentos[empresa] = copia_fundamentos[empresa].reset_index(drop=True)
   # base_dados = base_dados.append(copia_fundamentos[empresa])
# observe que na linha 8 tem o intervalo [1:-1] pois excluía o 1° tri de 2013 e o ultimo tri de 2020.
# ult_tri_fundamentos[empresa] = ult_tri_fundamentos[empresa][-1:] abaixo colocamos o ultomo tri de 2020.
# criamos uma nova variavel ult_tri_fundamentos = fundamentos.copy()
# Ao inves de criar a variavel base_dados que usamos antes, vamos chamar de ult_tri_base_dados.
# tudo que era copia_fundamentos mudamos para ult_tri_fundamentos.
# E tudo  que era  base_dados vai virar ult_tri_base_dados.
# Sempre que tratarmos uma tabela o (for) percorre nossa lista de fundamentos( que é um dic. com cada uma das empresas) e armazena dentro da variavel empresa, o nome da empresa que esta verificando no momento.
# pegamos depois a tabela daquela empresa , somente a ultima linha daquela tabela, ajeita o indice e adiciona na nova base de dados.
# Criamos uma lista_empresas = [] e sempre que fazemos um append na ult_tri_base_dados tb pegamos a lista_empresas = [] e adicionamos nela a empresa aual que estamos verificando.
ult_tri_fundamentos = fundamentos.copy()
ult_tri_base_dados = pd.DataFrame()
lista_empresas = []
for empresa in ult_tri_fundamentos:
    ult_tri_fundamentos[empresa] = ult_tri_fundamentos[empresa][-1:]
    ult_tri_fundamentos[empresa] = ult_tri_fundamentos[empresa].reset_index(drop=True)
    ult_tri_base_dados = ult_tri_base_dados.append(ult_tri_fundamentos[empresa])
    lista_empresas.append(empresa)
display(ult_tri_base_dados)
print(lista_empresas)

# %%
# lista top10 é a lista com os 10 itens dos fundamentos ou colunas que queremos usar pra prever.
# os indices estão todos corretos com 11 colunas pois está incluido a coluna de decisão, mas vamos remove-la, pois não é nisso objetivo.
# nosso objetivo é passar as informações das colunas para que o modelo possa prever quais as ações que deve comprar.
# Assim que o modelo escolheu a carteira que devemos comprar depois temos que comparar com o indice IBOVESPA para saber se foi uma decisão boa ou não.
ult_tri_base_dados = ult_tri_base_dados.reset_index(drop=True)
ult_tri_base_dados = ult_tri_base_dados[top10]
ult_tri_base_dados = ajustar_scaler(ult_tri_base_dados)
display(ult_tri_base_dados)

# %%
# lista top10 é a lista com os 10 itens dos fundamentos ou colunas que queremos usar pra prever.
# os indices estão todos corretos com 11 colunas pois está incluido a coluna de decisão, mas vamos remove-la, pois não é nisso objetivo.
# nosso objetivo é passar as informações das colunas para que o modelo possa prever quais as ações que deve comprar.
# Assim que o modelo escolheu a carteira que devemos comprar depois temos que comparar com o indice IBOVESPA para saber se foi uma decisão boa ou não.
ult_tri_base_dados = ult_tri_base_dados.reset_index(drop=True)
ult_tri_base_dados = ult_tri_base_dados[top10]
ult_tri_base_dados = ajustar_scaler(ult_tri_base_dados)
ult_tri_base_dados = ult_tri_base_dados.drop("Decisao", axis=1)
display(ult_tri_base_dados)

# %%
# Agora é só passar a tabela acima para o nosso modelo para realizar a previsão.
# Para cada linha deve prever se deve comprar ou não determinada ação.
# Veja que no previsoes_ult_tri que vai ser o modelo tunado passamos para ele a tabela acima, pois ja está sem a coluna de decisão.
# Ao não ter a coluna Decisão ja tem-se os valores de x que são  as caracteristicas que o modelo usa para faer a previsão.
# Veja que ao darmos um print vemos as previsões da variavel previsoes_ult_tri.
previsoes_ult_tri = modelo_tunado.predict(ult_tri_base_dados)
print(previsoes_ult_tri)

# %% [markdown]
# ###### veja que os valores de 2 significa comprar.
# ###### Os valores 0 não comprar.
# ###### A primeira empresa representada pelo 2, então compra. A segunda empresa que é 0 não compra e assim sucessivamente.
# ###### Agora precisamos saber quais empresas correspondentes a cada valor 0 e 2 na lista acima.
# ###### Veja que temos a lista de empresas que conversa com a lista de previsões. Ou seja, o primeiro item da lista de previsões corresponde ao primeiro item da lista de empresas. O segundo item da lista de previsões corresponde ao segundo item da lista de empresas e assim sucessivamente.
# ###### Veja o seguinte, esta correspondencia é por posição portanto:
# ###### for i, empresa in enumerate(lista_empresas). Ele vai pegar cada item da lista_empresa e armazena no i a posição da empresa com o valor de previsão.

# %%
previsoes_ult_tri = modelo_tunado.predict(ult_tri_base_dados)
print(previsoes_ult_tri)
for i, empresa in enumerate(lista_empresas):
    if previsoes_ult_tri[i] == 2:
        print(empresa)

# %% [markdown]
# ###### Veja  previsoes_ult_tri[ i ] == 2 manda comprar as empresas listadas na coluna acima.
# ###### Veja que previsoes_ult_tri[ i ] == 2 ja é a decisão, ou seja, se quisessemos comprar as ações só iríamos no Home Broker e compraríamos as ações indicadas acima.
# ###### So que ja passou-se o 1° tri de 2021 e ja podemos saber se a decisão de comprar foi boa ou ruim. Para sabermos isso é necessario criar uma carteira de ações em  que coloquemos o mesmo valor para cada empresa.
# ###### vamos dizer 1000 reais, quanto teriámos no final do 1º tri de 2021? mais de 1000 ou menos. Quanto a carteira deveria ter rendido neste periodo e quanto o IBOVESPA deveria ter rendido neste periodo.
# ###### Para saber isto vamos criar duas carteiras:
# ###### 1) carteira = [ ]
# ###### 2) carteira_inicial = [ ]
# ###### Qual será a lógica? para cada empresa que ele nos manda comprar vamos adicionar  1000,00  na carteira_inicial e adicionar o valor da cotação da empresa dentro de carteira. Ou seja, se tivesse colocado  1000,00 em 31/12/2020, quato teria na minha carteira = [ ] em 31/03/2021.
# ###### Portanto em carteira = [ ] teremos o valor atual da minha carteira e carteira_inicial = [ ] o valor inicial da carteira em 31/12/2020.

# %%
previsoes_ult_tri = modelo_tunado.predict(ult_tri_base_dados)
print(previsoes_ult_tri)

carteira = []
carteira_inicial = []

for i, empresa in enumerate(lista_empresas):
    if previsoes_ult_tri[i] == 2:
        print(empresa)
        carteira_inicial.append(1000)
        cotacao = cotacoes[empresa]
        cotacao = cotacao.set_index("Date")
        cotacao_inicial = cotacao.loc["2020-12-31", "Adj Close"]
        cotacao_final = cotacao.loc["2021-03-31", "Adj Close"]
        percentual = cotacao_final / cotacao_inicial
        carteira.append(1000 * percentual)
        
saldo_inicial = sum(carteira_inicial)
saldo_final = sum(carteira)
print(saldo_inicial, saldo_final)
print(saldo_final / saldo_inicial)

# %% [markdown]
# ###### Veja acima o quanto  a ação rendeu no periodo 31-12-2020 a 31-03-2021, será:   percentual = cotacao_final / cotacao_inicial
# ###### O valor que vamos colocar dentro da carteira é os R$ 1000,00 iniciais + o percentual de variação.
# ###### O resultado final de carteira inicial com  o valor a ser investido vezes o percentual de variação da ctaçãoda empresa no periodo que vai ser inserido na carteira final vai ocorrer o seguinte:
# ###### Veja que depois do for da celula anterior o modelo ja calculou o rendimeno de todas as ações.
# ###### Portanto o saldo inicial é o somatorio de todos os valores investidos inicialmente e saldo final vai ser a soma de nossa carteira atualizada.
# ###### Quanto foi o rendimento desta carteira?
# ###### Resposta: A carteira rendeu 4,5% até 31/03/2021

# %% [markdown]
# ### Agora vamos comparar a previsão de decisões com o IBOV

# %% [markdown]
# ###### O rendimento que tivemos acima com o rendimento do IBOVESPA.
# ###### Para fazer isto  cotação final / cotação inicial do IBOVESPA.
# ###### Veja abaixo:

# %%
variacao_ibov = df_ibov.loc["2021-03-31", "IBOV"] / df_ibov.loc["2020-12-31", "IBOV"]
print(variacao_ibov)

# %% [markdown]
# ###### Este resultado acima significa que criamos um modelo que em um  trimestre escolheu uma carteira de ações rendeu 4,6 % no mesmo periodo que o IBOVESPA caiu quase 3 % .

# %%
# # armazenar a inteligencia artificial( modelotunado)
import joblib
from joblib import dump, load
joblib.dump(modelo_tunado, "ia_carteiraacoes.joblib")
modelo_tunado = joblib.load("ia_carteiraacoes.joblib")

# %% [markdown]
# ###### Como o modelo  está criado, não há necessidade de rodar o codigo novamente para criar novamente o mesmo modelo de IA. Podemos armazenar a variavel modelo tunado na joblib, pois ela permite armazene uma variavel do python num arquivo do meu computador.
# ###### A proxima vez que usar a AI como iremos usar ? Vamos ler esse arquivo e pegar a AI pronta, vamos pegar os fundamentos das empresas naquele trimestre que quero prever vamos passar para um predict como  previsoes_ult_tri = modelo_tunado.predict(ult_tri_base_dados) nos diz quais as previsoes de ações que temos que comprar.
# ###### joblib.dump(modelo_tunado, "ia_carteiraacoes.joblib") salva o arquivo.
# ###### Quando quisermos usar o modelo de IA em outro codigo, ou seja, sem necessariamente usar este notebook?
# ###### Resposta: modelo_tunado = joblib.load("ia_carteiraacoes.joblib") , quando executarmos este codigo o modelo de AI ja está treinada, tunada , pronta pra faer um predict e aplicar ela.
